# %% [markdown]
# # Data Processing for Topic Model Test
#
# Getting the data from the repository...don't run unless you don't have the data!
#
# !apt-get -y install curl
#
# !curl -o BioMedSent/BioMedSentences.tar.zip http://i.stanford.edu/hazy/opendata/bmc/bmc_full_dddb_20150927_9651bf4a468cefcea30911050c2ca6db.tar.bzip2
#
# http://i.stanford.edu/hazy/opendata/pmc/pmc_dddb_full_20150927_3b20db570e2cb90ab81c5c6f63babc91.tar.bzip2

# %% [markdown]
# # Import Data
#
# This section defines the Sentence object used when importing and saving the data. Grab the files in a directory and process a subset of them.
#
# The only difference between this and the ETLScriptPapers is that punctuation is not stripped out, so we can differentiate between sentences for the readabilty scores.

# %%
#Import Statements
import string
import os
import pickle
from collections import defaultdict
from multiprocessing import Pool

#Sentence object definition for data import and processing 
class Sentence:
    def __init__(self, document, sentenceNumber, wordList, lemmaList, posList):
        self.document = document
        self.sentenceNumber = sentenceNumber
        self.wordList = wordList
        self.lemmaList = lemmaList
        self.posList = posList
        self.sentence = " ".join([word for word in wordList]) #if word not in string.punctuation
        self.lemmaSent = " ".join([word for word in lemmaList]) #if word not in string.punctuation

#Get the files we want to process and put them into a list of lists called sentList
fileList = os.listdir("../BioMedSent/")
sentList = []
fileList.sort()
for n in range(1,2):
    f = open("../BioMedSent/" + fileList[n], 'r')
    for line in f:
        sentList.append(line.split('\t'))

len(sentList)
# Out:
# 518828

# %% [markdown]
# Now that we have all of the sentences in a list of lists grab the first element of each sentence list (the document id) and add that to a docList. Make this docList a set so we have the number of unique documents.

# %%
docList = []
for thing in sentList:
    docList.append(thing[0])

len(set(docList))
# Out:
# 2189

# %% [markdown]
# # Process Data
#
# Define the processSent function for use by the multiprocessing part of the code. This function takes off some of the structure of parts of the data (removing the {,}, and ") and defines the Sentence object with all the appropriate parts.
#
# We then use 14 cores (if available) for the Pool object and apply the processSent function to every sentence.

# %%
sentObjList = []
def processSent(item):
    wordList = item[3].replace('"',"").lstrip("{").rstrip("}").split(",")
    wordList = filter(None, wordList)
    posList = item[4].split(",")
    lemmaList = item[6].replace('"',"").lstrip("{").rstrip("}").split(",")
    lemmaList = filter(None, lemmaList)
    return Sentence(item[0], item[1], wordList, lemmaList, posList)

po = Pool(6)
results = [po.apply_async(processSent, args = (sent,)) for sent in sentList]
po.close()
po.join()
output = [p.get() for p in results]
sentObjList = output
sentObjList[7].lemmaSent
# Out:
# 'we induce hypothyroidism follow by supplementation with 3 5-diiodothyronine ( t2 ) or 3 5 3 - triiodothyronine ( t3 ) in zebrafish expose to different chronic temperature .'

# %% [markdown]
# Now that the sentences are processed, we need to find which sections these sentences should be atributed. For most of these papers, section headers are one word sentences. We are looking for common section headers and saving the sentence numbers for that section in that document.

# %%
headingsDict = defaultdict(dict)

for sent in sentObjList:
    if len(sent.wordList) == 1:
        #print(sent.wordList)
        word = string.upper(sent.wordList[0]).strip()
        if word == 'INTRODUCTION' or word == 'BACKGROUND':
            headingsDict[sent.document]["introduction"] = sent.sentenceNumber
        elif word == 'METHODS':
            headingsDict[sent.document]["methods"] = sent.sentenceNumber
        elif word == 'RESULTS':
            headingsDict[sent.document]["results"] = sent.sentenceNumber
        elif word == 'DISCUSSION':
            headingsDict[sent.document]["discussion"] = sent.sentenceNumber
        elif word == 'CONCLUSION':
            headingsDict[sent.document]["conclusion"] = sent.sentenceNumber
        elif word == 'REFERENCES':
            headingsDict[sent.document]["references"] = sent.sentenceNumber
        

headingsDict.keys()
# Out:
# ['BMC_Infect_Dis_2002_Sep_4_2_18.nxml.txt.nlp',
#  'BMC_Med_Ethics_2009_Jul_6_10_9.nxml.txt.nlp',
#  'BMC_Pharmacol_Toxicol_2013_Sep_28_14_48.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Oct_31_12_281.nxml.txt.nlp',
#  'BMC_Bioinformatics_2003_Nov_7_4_55.nxml.txt.nlp',
#  'BMC_Genomics_2003_Apr_29_4_15.nxml.txt.nlp',
#  'BMC_Vet_Res_2009_Feb_4_5_7.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2011_Aug_22_11_67.nxml.txt.nlp',
#  'BMC_Ophthalmol_2014_Feb_17_14_16.nxml.txt.nlp',
#  'BMC_Nephrol_2012_Sep_21_13_116.nxml.txt.nlp',
#  'BMC_Evol_Biol_2011_Jul_1_11_188.nxml.txt.nlp',
#  'BMC_Biotechnol_2006_Jan_16_6_6.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_May_4_12(Suppl_1)_P69.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2013_Sep_16_13_114.nxml.txt.nlp',
#  'BMC_Proc_2013_Dec_4_7(Suppl_6)_P96.nxml.txt.nlp',
#  'BMC_Med_2007_Jan_1_5_1.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Mar_29_12_26.nxml.txt.nlp',
#  'BMC_Struct_Biol_2012_Nov_13_12_28.nxml.txt.nlp',
#  'BMC_Cancer_2004_May_21_4_23.nxml.txt.nlp',
#  'BMC_Public_Health_2012_May_21_12_278.nxml.txt.nlp',
#  'BMC_Geriatr_2014_Jan_10_14_3.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_O22.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2011_Mar_29_12_63.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2003_May_22_3_3.nxml.txt.nlp',
#  'BMC_Ear_Nose_Throat_Disord_2008_Sep_17_8_5.nxml.txt.nlp',
#  'BMC_Med_Educ_2007_Jul_25_7_24.nxml.txt.nlp',
#  'BMC_Cancer_2010_Oct_19_10_565.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Feb_13_14_160.nxml.txt.nlp',
#  'BMC_Genomics_2007_Jul_10_8_225.nxml.txt.nlp',
#  'BMC_Med_2013_Jul_18_11_167.nxml.txt.nlp',
#  'BMC_Clin_Pharmacol_2007_Oct_8_7_11.nxml.txt.nlp',
#  'BMC_Plant_Biol_2009_Nov_30_9_142.nxml.txt.nlp',
#  'BMC_Clin_Pathol_2006_Oct_30_6_7.nxml.txt.nlp',
#  'BMC_Endocr_Disord_2013_Mar_13_13_11.nxml.txt.nlp',
#  'BMC_Neurol_2014_Oct_14_14(1)_205.nxml.txt.nlp',
#  'BMC_Cell_Biol_2004_Jul_13_5_27.nxml.txt.nlp',
#  'BMC_Neurol_2012_Aug_10_12_72.nxml.txt.nlp',
#  'BMC_Mol_Biol_2002_Feb_18_3_2.nxml.txt.nlp',
#  'BMC_Med_Educ_2005_Jan_29_5_4.nxml.txt.nlp',
#  'BMC_Neurosci_2011_Jul_18_12(Suppl_1)_P109.nxml.txt.nlp',
#  'BMC_Genomics_2007_Oct_29_8_393.nxml.txt.nlp',
#  'BMC_Genomics_2007_Oct_15_8_372.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P280.nxml.txt.nlp',
#  'BMC_Evol_Biol_2014_Jan_14_14_7.nxml.txt.nlp',
#  'BMC_Proc_2014_Oct_1_8(Suppl_4)_P4.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_May_28_15(Suppl_7)_S12.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Jun_9_12(Suppl_3)_S6.nxml.txt.nlp',
#  'BMC_Med_Educ_2007_Oct_12_7_36.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P56.nxml.txt.nlp',
#  'BMC_Surg_2013_Oct_8_13(Suppl_2)_S21.nxml.txt.nlp',
#  'BMC_Neurosci_2008_Dec_3_9(Suppl_2)_S15.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Oct_27_13_286.nxml.txt.nlp',
#  'BMC_Proc_2014_Oct_1_8(Suppl_4)_P13.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Sep_25_11_727.nxml.txt.nlp',
#  'BMC_Neurosci_2010_Apr_28_11_55.nxml.txt.nlp',
#  'BMC_Public_Health_2010_May_27_10_283.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Feb_1_14_30.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2009_Nov_18_9_52.nxml.txt.nlp',
#  'BMC_Cancer_2010_Aug_30_10_465.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Feb_20_14_66.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Aug_27_10_256.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jan_12_10_11.nxml.txt.nlp',
#  'BMC_Neurol_2001_Nov_6_1_6.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Apr_26_11_264.nxml.txt.nlp',
#  'BMC_Gastroenterol_2011_Apr_17_11_40.nxml.txt.nlp',
#  'BMC_Bioinformatics_2005_Dec_1_6(Suppl_4)_S2.nxml.txt.nlp',
#  'BMC_Cancer_2006_Feb_24_6_42.nxml.txt.nlp',
#  'BMC_Dev_Biol_2006_Mar_16_6_15.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2010_Aug_4_10_225.nxml.txt.nlp',
#  'BMC_Genomics_2008_Jul_1_9_315.nxml.txt.nlp',
#  'BMC_Nephrol_2013_Jul_15_14_148.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jun_9_11_310.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2008_Mar_20_8_60.nxml.txt.nlp',
#  'BMC_Genomics_2013_Aug_8_14_539.nxml.txt.nlp',
#  'BMC_Genomics_2005_Aug_29_6_111.nxml.txt.nlp',
#  'BMC_Med_2013_Feb_28_11_57.nxml.txt.nlp',
#  'BMC_Neurosci_2013_Dec_5_14_152.nxml.txt.nlp',
#  'BMC_Genomics_2009_Jul_29_10_341.nxml.txt.nlp',
#  'BMC_Biotechnol_2007_Jun_18_7_34.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2011_Sep_20_11_75.nxml.txt.nlp',
#  'BMC_Geriatr_2014_Sep_20_14(1)_107.nxml.txt.nlp',
#  'BMC_Plant_Biol_2010_Dec_30_10_291.nxml.txt.nlp',
#  'BMC_Womens_Health_2010_Oct_26_10_30.nxml.txt.nlp',
#  'BMC_Cancer_2009_Jan_9_9_8.nxml.txt.nlp',
#  'BMC_Neurol_2014_Feb_25_14_36.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_May_23_14(Suppl_2)_P50.nxml.txt.nlp',
#  'BMC_Vet_Res_2013_Apr_4_9_64.nxml.txt.nlp',
#  'BMC_Infect_Dis_2011_Sep_30_11_259.nxml.txt.nlp',
#  'BMC_Pediatr_2009_Mar_18_9_22.nxml.txt.nlp',
#  'BMC_Microbiol_2010_Jan_12_10_6.nxml.txt.nlp',
#  'BMC_Med_Genomics_2011_Jan_11_4_4.nxml.txt.nlp',
#  'BMC_Neurol_2010_May_26_10_35.nxml.txt.nlp',
#  'BMC_Genomics_2012_Apr_24_13_142.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Feb_12_9_96.nxml.txt.nlp',
#  'BMC_Int_Health_Hum_Rights_2013_Aug_7_13_33.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Dec_19_14_358.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2004_Nov_8_4_30.nxml.txt.nlp',
#  'BMC_Genomics_2011_Apr_15_12_191.nxml.txt.nlp',
#  'BMC_Immunol_2010_Jul_7_11_36.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jan_26_11_53.nxml.txt.nlp',
#  'BMC_Public_Health_2014_May_20_14_473.nxml.txt.nlp',
#  'BMC_Res_Notes_2009_Apr_28_2_64.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Jan_24_9_46.nxml.txt.nlp',
#  'BMC_Genet_2003_Jun_28_4_11.nxml.txt.nlp',
#  'BMC_Infect_Dis_2007_Mar_13_7_17.nxml.txt.nlp',
#  'BMC_Neurosci_2010_Apr_23_11_51.nxml.txt.nlp',
#  'BMC_Plant_Biol_2004_Jun_1_4_10.nxml.txt.nlp',
#  'BMC_Genomics_2004_Nov_8_5_85.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2010_Sep_1_11_196.nxml.txt.nlp',
#  'BMC_Anesthesiol_2008_Feb_18_8_3.nxml.txt.nlp',
#  'BMC_Fam_Pract_2005_Jan_15_6_4.nxml.txt.nlp',
#  'BMC_Pulm_Med_2010_Feb_22_10_7.nxml.txt.nlp',
#  'BMC_Cancer_2005_Aug_21_5_108.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2013_Dec_1_13_501.nxml.txt.nlp',
#  'BMC_Microbiol_2010_Dec_30_10_329.nxml.txt.nlp',
#  'BMC_Pulm_Med_2011_Nov_24_11_53.nxml.txt.nlp',
#  'BMC_Genomics_2010_Dec_2_11(Suppl_4)_S18.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Jul_28_7_475.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Oct_15_10_297.nxml.txt.nlp',
#  'BMC_Endocr_Disord_2009_May_9_9_13.nxml.txt.nlp',
#  'BMC_Proc_2009_Jul_16_3(Suppl_4)_S7.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2014_Sep_27_15(1)_321.nxml.txt.nlp',
#  'BMC_Genomics_2006_Oct_31_7_279.nxml.txt.nlp',
#  'BMC_Psychiatry_2010_Aug_4_10_61.nxml.txt.nlp',
#  'BMC_Biochem_2001_Sep_3_2_8.nxml.txt.nlp',
#  'BMC_Genomics_2014_Aug_26_15(1)_717.nxml.txt.nlp',
#  'BMC_Genet_2009_Jul_6_10_33.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2006_Feb_22_6_13.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P221.nxml.txt.nlp',
#  'BMC_Infect_Dis_2006_Jan_11_6_4.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Oct_15_14(1)_549.nxml.txt.nlp',
#  'BMC_Genomics_2014_Sep_8_15(1)_769.nxml.txt.nlp',
#  'BMC_Genomics_2010_Dec_15_11_705.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Mar_30_10_82.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Apr_26_7_270.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P46.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Jul_11_14_222.nxml.txt.nlp',
#  'BMC_Psychiatry_2005_Oct_24_5_38.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Oct_23_14(1)_410.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2011_Oct_13_12_233.nxml.txt.nlp',
#  'BMC_Int_Health_Hum_Rights_2009_Nov_27_9_31.nxml.txt.nlp',
#  'BMC_Pulm_Med_2010_Apr_28_10_24.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jul_30_10_397.nxml.txt.nlp',
#  'BMC_Dev_Biol_2014_Feb_19_14_9.nxml.txt.nlp',
#  'BMC_Cancer_2013_Feb_18_13_80.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Aug_4_9_281.nxml.txt.nlp',
#  'BMC_Res_Notes_2009_Jul_7_2_124.nxml.txt.nlp',
#  'BMC_Public_Health_2006_May_19_6_135.nxml.txt.nlp',
#  'BMC_Public_Health_2007_Jul_2_7_133.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Nov_24_11_892.nxml.txt.nlp',
#  'BMC_Fam_Pract_2014_Dec_12_15(1)_204.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Dec_15_12_153.nxml.txt.nlp',
#  'BMC_Cancer_2010_Nov_2_10_599.nxml.txt.nlp',
#  'BMC_Gastroenterol_2013_Nov_9_13_156.nxml.txt.nlp',
#  'BMC_Cancer_2014_Dec_16_14(1)_966.nxml.txt.nlp',
#  'BMC_Public_Health_2010_Oct_6_10_591.nxml.txt.nlp',
#  'BMC_Immunol_2013_Nov_22_14_52.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Sep_11_13_226.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Mar_24_7_172.nxml.txt.nlp',
#  'BMC_Pulm_Med_2010_Nov_22_10_59.nxml.txt.nlp',
#  'BMC_Public_Health_2011_May_25_11_383.nxml.txt.nlp',
#  'BMC_Gastroenterol_2014_Feb_23_14_39.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2009_Oct_19_9_189.nxml.txt.nlp',
#  'BMC_Psychiatry_2013_Oct_8_13_251.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_May_23_14(Suppl_2)_P49.nxml.txt.nlp',
#  'BMC_Cancer_2007_Feb_5_7(Suppl_1)_A40.nxml.txt.nlp',
#  'BMC_Cell_Biol_2009_Jun_17_10_46.nxml.txt.nlp',
#  'BMC_Syst_Biol_2012_Dec_17_6(Suppl_3)_S5.nxml.txt.nlp',
#  'BMC_Dev_Biol_2011_May_25_11_31.nxml.txt.nlp',
#  'BMC_Mol_Biol_2009_Apr_28_10_36.nxml.txt.nlp',
#  'BMC_Immunol_2013_Jun_25_14_29.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Jul_25_13_178.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2008_May_24_9_73.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Aug_5_10_233.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Oct_28_14_314.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2011_Jun_27_11_50.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Mar_15_11_130.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2011_Jul_22_12_170.nxml.txt.nlp',
#  'BMC_Cancer_2013_Nov_2_13_518.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Jun_18_14_622.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Jan_9_14_4.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_May_27_14(Suppl_3)_E41.nxml.txt.nlp',
#  'BMC_Genomics_2007_Dec_20_8_470.nxml.txt.nlp',
#  'BMC_Med_Genomics_2014_Apr_7_7_17.nxml.txt.nlp',
#  'BMC_Evol_Biol_2009_Oct_12_9_248.nxml.txt.nlp',
#  'BMC_Bioinformatics_2003_Feb_19_4_6.nxml.txt.nlp',
#  'BMC_Public_Health_2006_Jun_21_6_163.nxml.txt.nlp',
#  'BMC_Nephrol_2011_Oct_28_12_60.nxml.txt.nlp',
#  'BMC_Cancer_2014_Mar_6_14_159.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Jan_20_12_27.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2014_Dec_9_15(1)_416.nxml.txt.nlp',
#  'BMC_Urol_2012_Mar_27_12_9.nxml.txt.nlp',
#  'BMC_Proc_2013_Apr_4_7(Suppl_2)_P57.nxml.txt.nlp',
#  'BMC_Infect_Dis_2009_Aug_6_9_122.nxml.txt.nlp',
#  'BMC_Fam_Pract_2013_Sep_8_14_134.nxml.txt.nlp',
#  'BMC_Womens_Health_2005_May_12_5_6.nxml.txt.nlp',
#  'BMC_Plant_Biol_2004_Apr_16_4_6.nxml.txt.nlp',
#  'BMC_Neurosci_2010_Jan_14_11_5.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Aug_2_11_613.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Mar_29_14_174.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P219.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2006_Jun_15_6_75.nxml.txt.nlp',
#  'BMC_Bioinformatics_2007_May_9_8(Suppl_3)_S3.nxml.txt.nlp',
#  'BMC_Evol_Biol_2014_Dec_17_14(1)_260.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Oct_12_11_793.nxml.txt.nlp',
#  'BMC_Cancer_2009_Jul_21_9_247.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Oct_17_14_297.nxml.txt.nlp',
#  'BMC_Genomics_2014_Apr_8_15_272.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2009_Sep_15_9_164.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Jun_7_12_411.nxml.txt.nlp',
#  'BMC_Public_Health_2008_Sep_24_8_333.nxml.txt.nlp',
#  'BMC_Plant_Biol_2013_Aug_21_13_119.nxml.txt.nlp',
#  'BMC_Cancer_2008_Dec_11_8_364.nxml.txt.nlp',
#  'BMC_Cancer_2013_Dec_6_13_580.nxml.txt.nlp',
#  'BMC_Cancer_2011_Nov_30_11_505.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2014_Jul_21_14_88.nxml.txt.nlp',
#  'BMC_Genomics_2007_Aug_30_8_299.nxml.txt.nlp',
#  'BMC_Ecol_2007_Jul_30_7_6.nxml.txt.nlp',
#  'BMC_Evol_Biol_2011_Jun_24_11_182.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2012_Jun_8_12_141.nxml.txt.nlp',
#  'BMC_Mol_Biol_2006_Jan_31_7_3.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2007_Apr_3_7_46.nxml.txt.nlp',
#  'BMC_Gastroenterol_2010_Mar_27_10_33.nxml.txt.nlp',
#  'BMC_Neurosci_2012_Jan_19_13_11.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_Mar_19_8_88.nxml.txt.nlp',
#  'BMC_Cancer_2013_Jan_10_13_14.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Aug_18_11_428.nxml.txt.nlp',
#  'BMC_Pediatr_2011_Nov_21_11_105.nxml.txt.nlp',
#  'BMC_Med_Genet_2011_Jun_29_12_88.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Jun_18_14_266.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2008_Jun_11_8_126.nxml.txt.nlp',
#  'BMC_Genet_2013_Jun_5_14_47.nxml.txt.nlp',
#  'BMC_Psychiatry_2005_Apr_26_5_21.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Jul_18_14_313.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Feb_23_14_69.nxml.txt.nlp',
#  'BMC_Proc_2014_Jun_17_8(Suppl_1)_S17.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Apr_29_10(Suppl_4)_S3.nxml.txt.nlp',
#  'BMC_Evol_Biol_2010_Jun_22_10_192.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Jul_21_9_255.nxml.txt.nlp',
#  'BMC_Bioinformatics_2003_Nov_20_4_57.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Dec_7_13(Suppl_17)_S23.nxml.txt.nlp',
#  'BMC_Gastroenterol_2007_Mar_26_7_12.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_4_10_258.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_May_16_9_238.nxml.txt.nlp',
#  'BMC_Ophthalmol_2014_Dec_8_14(1)_155.nxml.txt.nlp',
#  'BMC_Cancer_2009_Jan_7_9_6.nxml.txt.nlp',
#  'BMC_Public_Health_2008_Dec_8_8_402.nxml.txt.nlp',
#  'BMC_Microbiol_2012_Jan_18_12(Suppl_1)_S4.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Oct_7_11(Suppl_6)_S18.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Apr_4_14_117.nxml.txt.nlp',
#  'BMC_Ear_Nose_Throat_Disord_2012_Mar_26_12_4.nxml.txt.nlp',
#  'BMC_Microbiol_2012_Sep_11_12_204.nxml.txt.nlp',
#  'BMC_Fam_Pract_2013_Sep_14_14_136.nxml.txt.nlp',
#  'BMC_Cancer_2013_Jun_22_13_303.nxml.txt.nlp',
#  'BMC_Cancer_2011_Feb_25_11_85.nxml.txt.nlp',
#  'BMC_Evol_Biol_2011_Jul_18_11_212.nxml.txt.nlp',
#  'BMC_Biol_2010_May_21_8_66.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_May_10_12_111.nxml.txt.nlp',
#  'BMC_Pharmacol_2011_Sep_5_11(Suppl_2)_A39.nxml.txt.nlp',
#  'BMC_Pediatr_2013_Oct_9_13_163.nxml.txt.nlp',
#  'BMC_Cancer_2013_Apr_12_13_190.nxml.txt.nlp',
#  'BMC_Med_Ethics_2010_Oct_18_11_18.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Aug_15_11_647.nxml.txt.nlp',
#  'BMC_Nurs_2008_Jun_17_7_8.nxml.txt.nlp',
#  'BMC_Pediatr_2013_Oct_8_13_160.nxml.txt.nlp',
#  'BMC_Evol_Biol_2014_Nov_25_14(1)_238.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_7_10_261.nxml.txt.nlp',
#  'BMC_Public_Health_2008_Dec_8_8_403.nxml.txt.nlp',
#  'BMC_Med_Imaging_2013_Sep_11_13_30.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P55.nxml.txt.nlp',
#  'BMC_Cancer_2014_May_24_14_366.nxml.txt.nlp',
#  'BMC_Genomics_2011_Jan_13_12_32.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Dec_12_7(Suppl_4)_S22.nxml.txt.nlp',
#  'BMC_Microbiol_2013_Feb_7_13_29.nxml.txt.nlp',
#  'BMC_Med_Educ_2010_May_20_10_36.nxml.txt.nlp',
#  'BMC_Nephrol_2012_Apr_18_13_18.nxml.txt.nlp',
#  'BMC_Dev_Biol_2009_Jan_6_9_1.nxml.txt.nlp',
#  'BMC_Genet_2003_Apr_2_4_5.nxml.txt.nlp',
#  'BMC_Proc_2014_Jun_17_8(Suppl_1)_S18.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Mar_23_12_18.nxml.txt.nlp',
#  'BMC_Neurosci_2013_Apr_5_14_44.nxml.txt.nlp',
#  'BMC_Struct_Biol_2010_Nov_24_10_42.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Nov_27_13_317.nxml.txt.nlp',
#  'BMC_Biol_2014_May_29_12_40.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2010_Sep_17_10_52.nxml.txt.nlp',
#  'BMC_Cancer_2010_May_9_10_186.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2013_May_31_13(Suppl_2)_S15.nxml.txt.nlp',
#  'BMC_Immunol_2008_Sep_15_9_51.nxml.txt.nlp',
#  'BMC_Biol_2014_Apr_17_12_28.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2014_Jan_6_14_1.nxml.txt.nlp',
#  'BMC_Genomics_2013_Oct_25_14(Suppl_6)_S1.nxml.txt.nlp',
#  'BMC_Genomics_2014_Oct_6_15(1)_866.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Jun_6_6_223.nxml.txt.nlp',
#  'BMC_Public_Health_2006_Jul_21_6_191.nxml.txt.nlp',
#  'BMC_Bioinformatics_2004_Oct_8_5_147.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Oct_4_14(1)_372.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2014_Apr_4_14_129.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Sep_20_12_809.nxml.txt.nlp',
#  'BMC_Biol_2005_Aug_2_3_18.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Apr_4_11_211.nxml.txt.nlp',
#  'BMC_Surg_2013_Oct_8_13(Suppl_2)_S50.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Aug_27_9_353.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Jul_28_12_567.nxml.txt.nlp',
#  'BMC_Fam_Pract_2014_Jan_3_15_1.nxml.txt.nlp',
#  'BMC_Cancer_2012_Jun_12_12_236.nxml.txt.nlp',
#  'BMC_Genet_2006_Jun_14_7_38.nxml.txt.nlp',
#  'BMC_Cancer_2010_Feb_23_10_58.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Dec_8_15(Suppl_16)_S10.nxml.txt.nlp',
#  'BMC_Geriatr_2009_Apr_1_9(Suppl_1)_A16.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P320.nxml.txt.nlp',
#  'BMC_Microbiol_2013_May_24_13_118.nxml.txt.nlp',
#  'BMC_Med_Genet_2013_Jul_23_14_76.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Mar_22_11_60.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Dec_17_12_154.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Feb_4_14_114.nxml.txt.nlp',
#  'BMC_Genomics_2008_May_19_9_229.nxml.txt.nlp',
#  'BMC_Womens_Health_2009_Sep_25_9_28.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Sep_11_12_94.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Feb_23_10_67.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Sep_13_14(Suppl_11)_S7.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2014_Oct_4_15(1)_335.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jun_5_11_306.nxml.txt.nlp',
#  'BMC_Neurol_2014_Nov_18_14(1)_213.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Oct_25_10_306.nxml.txt.nlp',
#  'BMC_Gastroenterol_2001_Dec_13_1_14.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2004_Nov_16_4_20.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Aug_9_14_163.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Aug_5_13_205.nxml.txt.nlp',
#  'BMC_Bioinformatics_2005_Jan_5_6_2.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Jul_4_14_134.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2011_Oct_12_11_71.nxml.txt.nlp',
#  'BMC_Geriatr_2013_Jan_18_13_7.nxml.txt.nlp',
#  'BMC_Endocr_Disord_2008_Jul_11_8_7.nxml.txt.nlp',
#  'BMC_Vet_Res_2012_Sep_27_8_180.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Jun_13_14_249.nxml.txt.nlp',
#  'BMC_Cancer_2014_Oct_11_14(1)_759.nxml.txt.nlp',
#  'BMC_Cancer_2011_Jan_31_11_46.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_28_10_336.nxml.txt.nlp',
#  'BMC_Cancer_2010_Dec_12_10_677.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2012_Jul_23_12_214.nxml.txt.nlp',
#  'BMC_Res_Notes_2011_Oct_28_4_464.nxml.txt.nlp',
#  'BMC_Res_Notes_2012_Feb_21_5_110.nxml.txt.nlp',
#  'BMC_Gastroenterol_2010_May_11_10_44.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Sep_19_14(Suppl_6)_S12.nxml.txt.nlp',
#  'BMC_Gastroenterol_2011_Jul_27_11_85.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Nov_14_11_866.nxml.txt.nlp',
#  'BMC_Genomics_2013_Dec_12_14_872.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Mar_10_14_242.nxml.txt.nlp',
#  'BMC_Pharmacol_Toxicol_2012_Sep_17_13(Suppl_1)_A54.nxml.txt.nlp',
#  'BMC_Plant_Biol_2013_Oct_1_13_146.nxml.txt.nlp',
#  'BMC_Neurosci_2011_Nov_1_12_109.nxml.txt.nlp',
#  'BMC_Neurol_2010_Nov_5_10_111.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Apr_8_14_133.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Aug_23_11_664.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Jan_31_7_68.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2010_Sep_10_11_204.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2014_Jan_18_14_33.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2008_May_24_8_111.nxml.txt.nlp',
#  'BMC_Ecol_2012_Aug_18_12_17.nxml.txt.nlp',
#  'BMC_Psychiatry_2010_Dec_13_10_108.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Jun_8_12_326.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2010_Jun_13_11_117.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2009_Jun_18_9_18.nxml.txt.nlp',
#  'BMC_Genet_2007_Oct_12_8_69.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Feb_15_12(Suppl_1)_S20.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_Mar_21_8_90.nxml.txt.nlp',
#  'BMC_Microbiol_2013_Feb_8_13_32.nxml.txt.nlp',
#  'BMC_Genet_2009_Oct_5_10_63.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Nov_13_13_299.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Dec_16_13(Suppl_1)_P104.nxml.txt.nlp',
#  'BMC_Gastroenterol_2014_Mar_10_14_44.nxml.txt.nlp',
#  'BMC_Psychiatry_2013_Nov_22_13_315.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Nov_23_11_573.nxml.txt.nlp',
#  'BMC_Sports_Sci_Med_Rehabil_2014_Feb_22_6_7.nxml.txt.nlp',
#  'BMC_Public_Health_2013_Mar_21_13_249.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2011_Oct_11_11_93.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Feb_11_14_62.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2009_Nov_5_9(Suppl_1)_A5.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_O50.nxml.txt.nlp',
#  'BMC_Bioinformatics_2004_Jan_5_5_1.nxml.txt.nlp',
#  'BMC_Proc_2011_Nov_29_5(Suppl_9)_S4.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Sep_6_14(1)_223.nxml.txt.nlp',
#  'BMC_Pharmacol_Toxicol_2012_Sep_17_13(Suppl_1)_A20.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Jan_16_14_4.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Feb_17_7_80.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Sep_4_14(1)_331.nxml.txt.nlp',
#  'BMC_Genomics_2005_May_10_6_70.nxml.txt.nlp',
#  'BMC_Med_Genet_2008_Apr_10_9_25.nxml.txt.nlp',
#  'BMC_Evol_Biol_2007_Nov_14_7_225.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Oct_15_14(Suppl_15)_S2.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Mar_1_13_51.nxml.txt.nlp',
#  'BMC_Immunol_2002_May_2_3_4.nxml.txt.nlp',
#  'BMC_Proc_2009_Jul_24_3(Suppl_5)_S20.nxml.txt.nlp',
#  'BMC_Proc_2013_Dec_4_7(Suppl_6)_P28.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2012_Oct_2_12_111.nxml.txt.nlp',
#  'BMC_Urol_2014_Apr_4_14_29.nxml.txt.nlp',
#  'BMC_Genomics_2011_Oct_17_12_512.nxml.txt.nlp',
#  'BMC_Vet_Res_2006_Jun_8_2_17.nxml.txt.nlp',
#  'BMC_Cancer_2009_Jun_25_9_203.nxml.txt.nlp',
#  'BMC_Psychiatry_2007_Dec_19_7(Suppl_1)_S45.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_May_20_7_306.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Oct_15_14(Suppl_15)_S13.nxml.txt.nlp',
#  'BMC_Public_Health_2007_Sep_27_7_268.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Feb_16_7_73.nxml.txt.nlp',
#  'BMC_Vet_Res_2014_Jun_5_10_125.nxml.txt.nlp',
#  'BMC_Geriatr_2003_Oct_7_3_3.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jan_28_11_62.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2013_Oct_20_13_126.nxml.txt.nlp',
#  'BMC_Med_Genet_2013_Jul_19_14_75.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Oct_31_12_282.nxml.txt.nlp',
#  'BMC_Cancer_2011_Jul_6_11_287.nxml.txt.nlp',
#  'BMC_Pulm_Med_2012_Jul_20_12_34.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Oct_16_10_339.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Oct_13_14(1)_263.nxml.txt.nlp',
#  'BMC_Psychiatry_2005_Jun_20_5_28.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_May_21_6_202.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2012_Sep_10_12_71.nxml.txt.nlp',
#  'BMC_Med_2013_Apr_18_11_108.nxml.txt.nlp',
#  'BMC_Pediatr_2010_Feb_5_10_5.nxml.txt.nlp',
#  'BMC_Genomics_2014_Dec_1_15(1)_1044.nxml.txt.nlp',
#  'BMC_Public_Health_2012_May_9_12_342.nxml.txt.nlp',
#  'BMC_Fam_Pract_2014_May_3_15_82.nxml.txt.nlp',
#  'BMC_Med_2011_Jun_2_9_68.nxml.txt.nlp',
#  'BMC_Genomics_2010_Dec_22_11_723.nxml.txt.nlp',
#  'BMC_Cancer_2013_Jul_1_13_318.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Apr_12_15_106.nxml.txt.nlp',
#  'BMC_Med_Genet_2012_Oct_11_13_96.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Jun_13_14_252.nxml.txt.nlp',
#  'BMC_Fam_Pract_2014_Jun_17_15_122.nxml.txt.nlp',
#  'BMC_Cancer_2008_Feb_7_8_46.nxml.txt.nlp',
#  'BMC_Vet_Res_2013_Oct_9_9_202.nxml.txt.nlp',
#  'BMC_Gastroenterol_2001_Aug_1_1_6.nxml.txt.nlp',
#  'BMC_Med_Genet_2009_Dec_17_10_140.nxml.txt.nlp',
#  'BMC_Genet_2005_Dec_30_6(Suppl_1)_S126.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Jul_5_14_174.nxml.txt.nlp',
#  'BMC_Ear_Nose_Throat_Disord_2013_Mar_25_13_4.nxml.txt.nlp',
#  'BMC_Public_Health_2013_May_14_13_469.nxml.txt.nlp',
#  'BMC_Res_Notes_2011_Oct_6_4_385.nxml.txt.nlp',
#  'BMC_Genomics_2014_Apr_16_15_291.nxml.txt.nlp',
#  'BMC_Genomics_2008_Mar_20_9_135.nxml.txt.nlp',
#  'BMC_Neurol_2006_Apr_11_6_16.nxml.txt.nlp',
#  'BMC_Genet_2008_Oct_31_9_68.nxml.txt.nlp',
#  'BMC_Genet_2004_Nov_24_5_31.nxml.txt.nlp',
#  'BMC_Evol_Biol_2012_Oct_8_12_202.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_Nov_16_12_162.nxml.txt.nlp',
#  'BMC_Geriatr_2003_Dec_12_3_5.nxml.txt.nlp',
#  'BMC_Gastroenterol_2010_Oct_22_10_124.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2007_Jul_23_7_116.nxml.txt.nlp',
#  'BMC_Evol_Biol_2009_May_16_9_104.nxml.txt.nlp',
#  'BMC_Cancer_2014_Jun_13_14_430.nxml.txt.nlp',
#  'BMC_Neurol_2008_Oct_29_8_40.nxml.txt.nlp',
#  'BMC_Struct_Biol_2008_Jan_16_8_2.nxml.txt.nlp',
#  'BMC_Plant_Biol_2012_Jan_27_12_16.nxml.txt.nlp',
#  'BMC_Nephrol_2012_Mar_19_13_13.nxml.txt.nlp',
#  'BMC_Evol_Biol_2013_Apr_29_13_93.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_May_29_12_56.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2008_Apr_10_9_44.nxml.txt.nlp',
#  'BMC_Med_Genet_2011_Jul_14_12_95.nxml.txt.nlp',
#  'BMC_Urol_2007_Jul_24_7_12.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Feb_25_9_114.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Jan_28_9_56.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Jan_3_11_1.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Feb_14_13_86.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_Sep_17_8_252.nxml.txt.nlp',
#  'BMC_Bioinformatics_2007_May_3_8(Suppl_2)_S11.nxml.txt.nlp',
#  'BMC_Fam_Pract_2011_Sep_21_12_97.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Jan_24_11_14.nxml.txt.nlp',
#  'BMC_Mol_Biol_2006_Nov_29_7_45.nxml.txt.nlp',
#  'BMC_Genet_2013_Aug_9_14_68.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Aug_13_9_293.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Feb_15_14_30.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2001_Nov_8_1_4.nxml.txt.nlp',
#  'BMC_Mol_Biol_2007_Jun_5_8_46.nxml.txt.nlp',
#  'BMC_Med_Genet_2006_Feb_10_7_9.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2010_Jul_23_11_169.nxml.txt.nlp',
#  'BMC_Clin_Pathol_2007_Nov_12_7_9.nxml.txt.nlp',
#  'BMC_Dermatol_2011_Jun_15_11_13.nxml.txt.nlp',
#  'BMC_Public_Health_2010_Apr_26_10_205.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Jun_3_13_125.nxml.txt.nlp',
#  'BMC_Fam_Pract_2013_May_16_14_62.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jan_18_11(Suppl_1)_S50.nxml.txt.nlp',
#  'BMC_Proc_2011_Nov_22_5(Suppl_8)_P96.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2008_Oct_2_9_133.nxml.txt.nlp',
#  'BMC_Res_Notes_2009_Sep_24_2_193.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2009_Jan_22_9_6.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Apr_13_12_96.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Apr_29_11_218.nxml.txt.nlp',
#  'BMC_Vet_Res_2013_Oct_7_9_196.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2011_Jan_31_11_14.nxml.txt.nlp',
#  'BMC_Med_Imaging_2012_Jul_24_12_20.nxml.txt.nlp',
#  'BMC_Anesthesiol_2001_Oct_26_1_2.nxml.txt.nlp',
#  'BMC_Psychiatry_2007_May_22_7_20.nxml.txt.nlp',
#  'BMC_Physiol_2003_Oct_3_3_10.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2011_Dec_30_11_176.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_Jul_10_12_87.nxml.txt.nlp',
#  'BMC_Infect_Dis_2001_Sep_25_1_17.nxml.txt.nlp',
#  'BMC_Cancer_2010_Nov_3_10_601.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2012_Sep_6_12_305.nxml.txt.nlp',
#  'BMC_Ophthalmol_2014_Mar_6_14_25.nxml.txt.nlp',
#  'BMC_Cancer_2012_Jan_20_12_32.nxml.txt.nlp',
#  'BMC_Dev_Biol_2007_Jul_16_7_85.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jan_18_11(Suppl_1)_S33.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Nov_20_14_335.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Jan_10_15(Suppl_1)_S12.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_Oct_23_12_148.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Dec_4_7(1)_876.nxml.txt.nlp',
#  'BMC_Infect_Dis_2009_Apr_21_9_46.nxml.txt.nlp',
#  'BMC_Genomics_2013_May_16_14_334.nxml.txt.nlp',
#  'BMC_Geriatr_2009_Jul_28_9_33.nxml.txt.nlp',
#  'BMC_Pharmacol_2009_Aug_11_9(Suppl_1)_S37.nxml.txt.nlp',
#  'BMC_Cancer_2014_Jan_16_14_28.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2008_Mar_5_8_10.nxml.txt.nlp',
#  'BMC_Fam_Pract_2012_Dec_20_13_123.nxml.txt.nlp',
#  'BMC_Neurosci_2005_May_6_6_33.nxml.txt.nlp',
#  'BMC_Neurosci_2005_May_28_6_37.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Feb_25_11(Suppl_1)_S5.nxml.txt.nlp',
#  'BMC_Cancer_2008_Jun_30_8_183.nxml.txt.nlp',
#  'BMC_Nephrol_2012_Jul_7_13_56.nxml.txt.nlp',
#  'BMC_Med_2013_Apr_18_11_107.nxml.txt.nlp',
#  'BMC_Pharmacol_2009_Aug_11_9(Suppl_1)_P64.nxml.txt.nlp',
#  'BMC_Cancer_2014_Mar_26_14_224.nxml.txt.nlp',
#  'BMC_Syst_Biol_2013_Dec_12_7_137.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Jun_21_14_635.nxml.txt.nlp',
#  'BMC_Genomics_2007_Aug_23_8_289.nxml.txt.nlp',
#  'BMC_Psychol_2014_Nov_29_2(1)_53.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2012_Mar_22_13_41.nxml.txt.nlp',
#  'BMC_Med_2013_May_24_11_138.nxml.txt.nlp',
#  'BMC_Biotechnol_2013_Nov_12_13_98.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Mar_13_12_190.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_22_10_321.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Apr_11_12_40.nxml.txt.nlp',
#  'BMC_Pharmacol_2011_Aug_1_11(Suppl_1)_P55.nxml.txt.nlp',
#  'BMC_Cancer_2001_Jun_19_1_5.nxml.txt.nlp',
#  'BMC_Cancer_2013_Nov_10_13_537.nxml.txt.nlp',
#  'BMC_Fam_Pract_2014_Nov_12_15(1)_172.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Nov_13_6_459.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Jul_10_12_66.nxml.txt.nlp',
#  'BMC_Cancer_2006_Oct_9_6_242.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2009_Jul_1_9_112.nxml.txt.nlp',
#  'BMC_Neurosci_2014_Jun_30_15_82.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Oct_24_12_269.nxml.txt.nlp',
#  'BMC_Pharmacol_2003_Jun_14_3_7.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2013_Sep_3_13_100.nxml.txt.nlp',
#  'BMC_Int_Health_Hum_Rights_2010_Dec_13_10(Suppl_1)_S8.nxml.txt.nlp',
#  'BMC_Genomics_2008_May_16_9_225.nxml.txt.nlp',
#  'BMC_Cancer_2008_Nov_28_8_355.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Jun_12_9_183.nxml.txt.nlp',
#  'BMC_Bioinformatics_2007_Apr_30_8_140.nxml.txt.nlp',
#  'BMC_Biotechnol_2011_May_21_11_56.nxml.txt.nlp',
#  'BMC_Plant_Biol_2014_Dec_31_14(1)_387.nxml.txt.nlp',
#  'BMC_Neurol_2012_Jun_18_12_39.nxml.txt.nlp',
#  'BMC_Anesthesiol_2014_Sep_18_14_78.nxml.txt.nlp',
#  'BMC_Vet_Res_2013_Nov_18_9_231.nxml.txt.nlp',
#  'BMC_Microbiol_2009_Jul_7_9_132.nxml.txt.nlp',
#  'BMC_Neurosci_2010_Apr_8_11_48.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Dec_12_12_348.nxml.txt.nlp',
#  'BMC_Cancer_2006_Apr_7_6_87.nxml.txt.nlp',
#  'BMC_Med_Genet_2010_Jun_14_11_94.nxml.txt.nlp',
#  'BMC_Genomics_2008_May_1_9_203.nxml.txt.nlp',
#  'BMC_Infect_Dis_2007_Nov_19_7_136.nxml.txt.nlp',
#  'BMC_Cancer_2011_Sep_24_11_407.nxml.txt.nlp',
#  'BMC_Psychiatry_2010_Mar_8_10_20.nxml.txt.nlp',
#  'BMC_Mol_Biol_2008_Mar_26_9_30.nxml.txt.nlp',
#  'BMC_Gastroenterol_2011_Jul_19_11_84.nxml.txt.nlp',
#  'BMC_Neurosci_2006_Mar_5_7_21.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_May_11_11_243.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_May_9_14(Suppl_8)_S4.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Sep_4_10_279.nxml.txt.nlp',
#  'BMC_Public_Health_2013_Jan_21_13_55.nxml.txt.nlp',
#  'BMC_Med_Genet_2010_Sep_20_11_133.nxml.txt.nlp',
#  'BMC_Biotechnol_2011_Jun_27_11_71.nxml.txt.nlp',
#  'BMC_Urol_2014_Jan_3_14_2.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_23_10_322.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Sep_19_15(1)_311.nxml.txt.nlp',
#  'BMC_Neurosci_2006_May_4_7_37.nxml.txt.nlp',
#  'BMC_Public_Health_2009_May_20_9_147.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Oct_15_14(Suppl_7)_P76.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Oct_2_12_235.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Sep_28_14(1)_240.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_May_30_7_321.nxml.txt.nlp',
#  'BMC_Pharmacol_2010_Nov_16_10(Suppl_1)_A4.nxml.txt.nlp',
#  'BMC_Syst_Biol_2008_Aug_18_2_75.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Oct_30_14(1)_502.nxml.txt.nlp',
#  'BMC_Genomics_2013_Jul_18_14_489.nxml.txt.nlp',
#  'BMC_Biol_2011_Feb_22_9_11.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Jun_6_7_343.nxml.txt.nlp',
#  'BMC_Biotechnol_2014_Jan_9_14_1.nxml.txt.nlp',
#  'BMC_Fam_Pract_2007_Oct_10_8_59.nxml.txt.nlp',
#  'BMC_Pediatr_2014_May_29_14_135.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_May_23_11_120.nxml.txt.nlp',
#  'BMC_Ecol_2008_Dec_29_8_23.nxml.txt.nlp',
#  'BMC_Proc_2009_Dec_15_3(Suppl_7)_S36.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Jun_18_14_151.nxml.txt.nlp',
#  'BMC_Genomics_2014_Nov_23_15(1)_1014.nxml.txt.nlp',
#  'BMC_Anesthesiol_2013_Nov_11_13_41.nxml.txt.nlp',
#  'BMC_Cell_Biol_2014_Mar_25_15_11.nxml.txt.nlp',
#  'BMC_Genomics_2013_Feb_6_14_83.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Jan_11_10_15.nxml.txt.nlp',
#  'BMC_Neurol_2012_Nov_21_12_141.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2008_Oct_15_9_139.nxml.txt.nlp',
#  'BMC_Clin_Pharmacol_2007_Jun_12_7_5.nxml.txt.nlp',
#  'BMC_Pulm_Med_2014_Apr_24_14_68.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Sep_11_13_225.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Sep_6_14(1)_185.nxml.txt.nlp',
#  'BMC_Proc_2011_Jan_10_5(Suppl_1)_P108.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Mar_5_13_119.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Jan_7_10_7.nxml.txt.nlp',
#  'BMC_Cell_Biol_2007_Jul_10_8(Suppl_1)_S9.nxml.txt.nlp',
#  'BMC_Cell_Biol_2007_Jun_1_8_20.nxml.txt.nlp',
#  'BMC_Med_Educ_2013_Jul_30_13_103.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Mar_31_14_175.nxml.txt.nlp',
#  'BMC_Cell_Biol_2010_Jun_24_11_45.nxml.txt.nlp',
#  'BMC_Biol_2012_Jun_25_10_59.nxml.txt.nlp',
#  'BMC_Microbiol_2010_Jul_27_10_201.nxml.txt.nlp',
#  'BMC_Cell_Biol_2014_Feb_11_15_5.nxml.txt.nlp',
#  'BMC_Syst_Biol_2012_Jul_18_6_87.nxml.txt.nlp',
#  'BMC_Ear_Nose_Throat_Disord_2007_Mar_13_7_2.nxml.txt.nlp',
#  'BMC_Genomics_2010_Dec_19_11_713.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Sep_29_15(Suppl_10)_P22.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2007_Apr_30_7_17.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Jul_24_7_355.nxml.txt.nlp',
#  'BMC_Endocr_Disord_2013_May_8_13_16.nxml.txt.nlp',
#  'BMC_Genomics_2014_Oct_2_15(1)_838.nxml.txt.nlp',
#  'BMC_Dev_Biol_2005_Sep_12_5_19.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Apr_24_14_140.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Sep_6_11_689.nxml.txt.nlp',
#  'BMC_Neurol_2009_Feb_10_9_7.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_May_9_12_46.nxml.txt.nlp',
#  'BMC_Ecol_2010_Feb_1_10_3.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Oct_26_11_830.nxml.txt.nlp',
#  'BMC_Nephrol_2014_Jan_15_15_16.nxml.txt.nlp',
#  'BMC_Neurol_2011_Jun_23_11_77.nxml.txt.nlp',
#  'BMC_Pediatr_2010_Aug_23_10_62.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P87.nxml.txt.nlp',
#  'BMC_Genomics_2014_Aug_29_15(1)_738.nxml.txt.nlp',
#  'BMC_Psychiatry_2014_Dec_6_14(1)_332.nxml.txt.nlp',
#  'BMC_Genomics_2012_Jul_30_13_351.nxml.txt.nlp',
#  'BMC_Proc_2011_Jan_10_5(Suppl_1)_P86.nxml.txt.nlp',
#  'BMC_Gastroenterol_2010_Mar_7_10_27.nxml.txt.nlp',
#  'BMC_Gastroenterol_2013_Jun_24_13_105.nxml.txt.nlp',
#  'BMC_Microbiol_2008_Nov_6_8_192.nxml.txt.nlp',
#  'BMC_Med_Genet_2009_Feb_27_10_18.nxml.txt.nlp',
#  'BMC_Immunol_2013_Nov_18_14_51.nxml.txt.nlp',
#  'BMC_Public_Health_2009_May_14_9_143.nxml.txt.nlp',
#  'BMC_Pharmacol_Toxicol_2012_Sep_17_13(Suppl_1)_A71.nxml.txt.nlp',
#  'BMC_Infect_Dis_2010_Mar_6_10_51.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Jan_31_12_39.nxml.txt.nlp',
#  'BMC_Genomics_2009_Mar_16_10_111.nxml.txt.nlp',
#  'BMC_Cell_Biol_2009_Jun_2_10_43.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Jan_30_9_42.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2013_May_6_13_167.nxml.txt.nlp',
#  'BMC_Gastroenterol_2013_Jun_11_13_100.nxml.txt.nlp',
#  'BMC_Syst_Biol_2013_Jun_19_7_47.nxml.txt.nlp',
#  'BMC_Med_2010_Jun_16_8_36.nxml.txt.nlp',
#  'BMC_Fam_Pract_2013_Oct_20_14_157.nxml.txt.nlp',
#  'BMC_Neurol_2012_Jul_28_12_62.nxml.txt.nlp',
#  'BMC_Psychiatry_2009_Jun_7_9_33.nxml.txt.nlp',
#  'BMC_Psychiatry_2009_May_29_9_28.nxml.txt.nlp',
#  'BMC_Genet_2014_Dec_10_15(1)_133.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_May_8_13_84.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Aug_20_13_383.nxml.txt.nlp',
#  'BMC_Womens_Health_2008_Apr_15_8_7.nxml.txt.nlp',
#  'BMC_Fam_Pract_2012_Mar_28_13_27.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Oct_29_10_362.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Jan_21_9_26.nxml.txt.nlp',
#  'BMC_Genomics_2010_Dec_2_11_684.nxml.txt.nlp',
#  'BMC_Infect_Dis_2008_May_14_8_65.nxml.txt.nlp',
#  'BMC_Microbiol_2009_May_21_9_103.nxml.txt.nlp',
#  'BMC_Cancer_2010_Nov_26_10_652.nxml.txt.nlp',
#  'BMC_Genomics_2014_Mar_19_15_212.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Dec_16_13(Suppl_1)_P83.nxml.txt.nlp',
#  'BMC_Cancer_2014_Jul_1_14_477.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Mar_6_9_142.nxml.txt.nlp',
#  'BMC_Med_2013_Sep_23_11_209.nxml.txt.nlp',
#  'BMC_Urol_2011_Dec_7_11_25.nxml.txt.nlp',
#  'BMC_Med_Genet_2011_Jul_25_12_99.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Nov_4_14(1)_282.nxml.txt.nlp',
#  'BMC_Med_2003_Dec_23_1_3.nxml.txt.nlp',
#  'BMC_Syst_Biol_2013_Dec_13_7(Suppl_6)_S13.nxml.txt.nlp',
#  'BMC_Genomics_2013_Sep_17_14_628.nxml.txt.nlp',
#  'BMC_Neurosci_2011_Apr_14_12_31.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Jan_16_14_41.nxml.txt.nlp',
#  'BMC_Pharmacol_2011_Sep_5_11(Suppl_2)_A32.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P194.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2013_Apr_17_13_49.nxml.txt.nlp',
#  'BMC_Bioinformatics_2003_Sep_10_4_40.nxml.txt.nlp',
#  'BMC_Microbiol_2012_Feb_1_12_19.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Jun_19_14_153.nxml.txt.nlp',
#  'BMC_Nephrol_2013_Sep_17_14_197.nxml.txt.nlp',
#  'BMC_Bioinformatics_2012_Sep_7_13(Suppl_14)_S7.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Dec_12_14(1)_250.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Dec_16_11_599.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2012_Mar_31_12_41.nxml.txt.nlp',
#  'BMC_Med_Genomics_2013_May_7_6(Suppl_2)_S6.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Dec_9_14(1)_1251.nxml.txt.nlp',
#  'BMC_Dermatol_2009_Apr_2_9_3.nxml.txt.nlp',
#  'BMC_Genomics_2011_Aug_24_12_431.nxml.txt.nlp',
#  'BMC_Struct_Biol_2013_May_14_13_8.nxml.txt.nlp',
#  'BMC_Biotechnol_2011_Mar_30_11_30.nxml.txt.nlp',
#  'BMC_Bioinformatics_2005_Jul_27_6_192.nxml.txt.nlp',
#  'BMC_Evol_Biol_2011_May_12_11_122.nxml.txt.nlp',
#  'BMC_Genomics_2009_Mar_13_10_107.nxml.txt.nlp',
#  'BMC_Infect_Dis_2007_Oct_23_7_119.nxml.txt.nlp',
#  'BMC_Biol_2014_Jan_27_12_5.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Jan_3_6_3.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P174.nxml.txt.nlp',
#  'BMC_Med_2011_Apr_18_9_40.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Feb_27_14_71.nxml.txt.nlp',
#  'BMC_Med_Genet_2005_Dec_2_6_41.nxml.txt.nlp',
#  'BMC_Biophys_2013_Aug_19_6_11.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2005_May_31_5_11.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P203.nxml.txt.nlp',
#  'BMC_Cell_Biol_2008_Sep_13_9_49.nxml.txt.nlp',
#  'BMC_Cell_Biol_2009_Feb_19_10_13.nxml.txt.nlp',
#  'BMC_Genomics_2006_May_2_7_101.nxml.txt.nlp',
#  'BMC_Gastroenterol_2007_Jan_31_7_4.nxml.txt.nlp',
#  'BMC_Public_Health_2013_Mar_16_13_232.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2014_Feb_4_14_44.nxml.txt.nlp',
#  'BMC_Genomics_2013_Jan_21_14(Suppl_1)_S15.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Jul_16_12_156.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2004_Aug_6_4_14.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Aug_10_9_288.nxml.txt.nlp',
#  'BMC_Evol_Biol_2010_Jul_28_10_228.nxml.txt.nlp',
#  'BMC_Public_Health_2013_Mar_19_13_241.nxml.txt.nlp',
#  'BMC_Cancer_2012_Nov_2_12_505.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2006_Dec_21_6_41.nxml.txt.nlp',
#  'BMC_Cancer_2007_Jan_19_7_15.nxml.txt.nlp',
#  'BMC_Cancer_2014_Feb_15_14_92.nxml.txt.nlp',
#  'BMC_Clin_Pharmacol_2011_Aug_4_11_11.nxml.txt.nlp',
#  'BMC_Pediatr_2009_Jun_25_9_42.nxml.txt.nlp',
#  'BMC_Nephrol_2014_Sep_26_15(1)_155.nxml.txt.nlp',
#  'BMC_Nephrol_2011_Dec_19_12_69.nxml.txt.nlp',
#  'BMC_Res_Notes_2011_Sep_13_4_358.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2014_May_6_14_63.nxml.txt.nlp',
#  'BMC_Microbiol_2009_Apr_20_9_74.nxml.txt.nlp',
#  'BMC_Mol_Biol_2009_Oct_25_10_97.nxml.txt.nlp',
#  'BMC_Genomics_2013_Mar_13_14_171.nxml.txt.nlp',
#  'BMC_Bioinformatics_2007_May_9_8_151.nxml.txt.nlp',
#  'BMC_Cancer_2010_Dec_23_10_691.nxml.txt.nlp',
#  'BMC_Cancer_2011_Oct_12_11_441.nxml.txt.nlp',
#  'BMC_Plant_Biol_2010_Aug_9_10_165.nxml.txt.nlp',
#  'BMC_Struct_Biol_2009_Oct_7_9_64.nxml.txt.nlp',
#  'BMC_Gastroenterol_2011_Dec_21_11_139.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Nov_27_12(Suppl_2)_A39.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2010_Nov_15_10_69.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2013_Oct_20_13_192.nxml.txt.nlp',
#  'BMC_Cancer_2013_Feb_22_13_85.nxml.txt.nlp',
#  'BMC_Struct_Biol_2005_Jun_28_5_11.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Oct_7_10_319.nxml.txt.nlp',
#  'BMC_Cell_Biol_2009_Jun_19_10_48.nxml.txt.nlp',
#  'BMC_Cell_Biol_2008_Oct_14_9_58.nxml.txt.nlp',
#  'BMC_Genet_2003_Dec_31_4(Suppl_1)_S99.nxml.txt.nlp',
#  'BMC_Public_Health_2013_Jun_8_13_562.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Nov_20_12_1002.nxml.txt.nlp',
#  'BMC_Neurol_2014_Oct_7_14(1)_203.nxml.txt.nlp',
#  'BMC_Genomics_2014_Jan_23_15_59.nxml.txt.nlp',
#  'BMC_Cancer_2014_Jul_15_14_514.nxml.txt.nlp',
#  'BMC_Struct_Biol_2014_Jan_17_14_3.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Feb_14_14(Suppl_1)_A2.nxml.txt.nlp',
#  'BMC_Evol_Biol_2009_Jan_2_9_1.nxml.txt.nlp',
#  'BMC_Chem_Biol_2009_Feb_12_9_3.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_May_10_6_194.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Aug_10_11_421.nxml.txt.nlp',
#  'BMC_Pulm_Med_2010_Jul_26_10_38.nxml.txt.nlp',
#  'BMC_Syst_Biol_2012_Dec_15_6_154.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2010_Feb_9_10_36.nxml.txt.nlp',
#  'BMC_Med_Educ_2013_Dec_21_13_171.nxml.txt.nlp',
#  'BMC_Pharmacol_2009_Aug_11_9(Suppl_1)_P66.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2011_May_12_11_38.nxml.txt.nlp',
#  'BMC_Surg_2014_Feb_20_14_10.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Mar_28_6_124.nxml.txt.nlp',
#  'BMC_Struct_Biol_2013_Nov_8_13(Suppl_1)_S2.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_Jul_8_8_196.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Dec_22_10_442.nxml.txt.nlp',
#  'BMC_Public_Health_2014_Feb_18_14_174.nxml.txt.nlp',
#  'BMC_Dev_Biol_2013_Jul_22_13_29.nxml.txt.nlp',
#  'BMC_Neurosci_2006_Mar_30_7_28.nxml.txt.nlp',
#  'BMC_Cancer_2011_Nov_7_11_477.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2006_Jun_6_6_67.nxml.txt.nlp',
#  'BMC_Gastroenterol_2012_Jul_12_12_89.nxml.txt.nlp',
#  'BMC_Med_2009_Dec_10_7_76.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Dec_18_7(Suppl_5)_S16.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P259.nxml.txt.nlp',
#  'BMC_Int_Health_Hum_Rights_2009_Aug_5_9_16.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2004_Dec_13_4_28.nxml.txt.nlp',
#  'BMC_Infect_Dis_2013_Jul_31_13_356.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_Jul_30_8_223.nxml.txt.nlp',
#  'BMC_Proc_2011_Jan_10_5(Suppl_1)_P64.nxml.txt.nlp',
#  'BMC_Cell_Biol_2008_Sep_23_9_54.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Jul_4_11_156.nxml.txt.nlp',
#  'BMC_Plant_Biol_2014_Apr_28_14_109.nxml.txt.nlp',
#  'BMC_Genomics_2013_Oct_16_14(Suppl_5)_S4.nxml.txt.nlp',
#  'BMC_Microbiol_2005_Oct_3_5_53.nxml.txt.nlp',
#  'BMC_Evol_Biol_2014_Oct_12_14(1)_218.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Nov_5_15(1)_351.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Aug_7_7_494.nxml.txt.nlp',
#  'BMC_Psychiatry_2010_Jan_14_10_5.nxml.txt.nlp',
#  'BMC_Oral_Health_2014_Jan_11_14_2.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_Sep_3_14(1)_478.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Jun_5_7_340.nxml.txt.nlp',
#  'BMC_Public_Health_2012_Oct_12_12_868.nxml.txt.nlp',
#  'BMC_Mol_Biol_2008_Mar_13_9_29.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2014_Apr_6_14_131.nxml.txt.nlp',
#  'BMC_Med_Genet_2010_Sep_22_11_136.nxml.txt.nlp',
#  'BMC_Nephrol_2008_Aug_25_9_10.nxml.txt.nlp',
#  'BMC_Vet_Res_2013_Apr_10_9_71.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Nov_4_11_302.nxml.txt.nlp',
#  'BMC_Cell_Biol_2012_Nov_6_13_31.nxml.txt.nlp',
#  'BMC_Cancer_2009_Jun_18_9_195.nxml.txt.nlp',
#  'BMC_Surg_2010_Oct_22_10_30.nxml.txt.nlp',
#  'BMC_Neurosci_2010_Dec_31_11_157.nxml.txt.nlp',
#  'BMC_Ecol_2014_Mar_18_14_7.nxml.txt.nlp',
#  'BMC_Plant_Biol_2010_Mar_11_10_45.nxml.txt.nlp',
#  'BMC_Public_Health_2011_Nov_14_11_864.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_May_5_7_283.nxml.txt.nlp',
#  'BMC_Microbiol_2012_May_30_12_90.nxml.txt.nlp',
#  'BMC_Cancer_2014_Aug_29_14(1)_634.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2002_Oct_23_2_7.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P213.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Oct_8_10(Suppl_11)_S15.nxml.txt.nlp',
#  'BMC_Med_Genet_2010_Jan_20_11_11.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Oct_21_15(Suppl_11)_S13.nxml.txt.nlp',
#  'BMC_Bioinformatics_2014_Apr_14_15_108.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Oct_30_6_438.nxml.txt.nlp',
#  'BMC_Genomics_2011_Dec_19_12_610.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2013_Aug_13_13_58.nxml.txt.nlp',
#  'BMC_Pediatr_2011_Feb_2_11_9.nxml.txt.nlp',
#  'BMC_Microbiol_2013_Apr_22_13_89.nxml.txt.nlp',
#  'BMC_Neurosci_2011_May_31_12_51.nxml.txt.nlp',
#  'BMC_Public_Health_2006_Feb_24_6_45.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Apr_14_7_236.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_O54.nxml.txt.nlp',
#  'BMC_Public_Health_2010_Nov_5_10_677.nxml.txt.nlp',
#  'BMC_Neurosci_2001_Dec_18_2_21.nxml.txt.nlp',
#  'BMC_Nephrol_2013_Jul_15_14_149.nxml.txt.nlp',
#  'BMC_Public_Health_2011_May_7_11_279.nxml.txt.nlp',
#  'BMC_Bioinformatics_2003_Apr_29_4_15.nxml.txt.nlp',
#  'BMC_Med_Imaging_2013_Mar_13_13_9.nxml.txt.nlp',
#  'BMC_Med_Educ_2014_Aug_7_14_162.nxml.txt.nlp',
#  'BMC_Psychiatry_2010_Feb_23_10_16.nxml.txt.nlp',
#  'BMC_Public_Health_2009_Dec_30_9_491.nxml.txt.nlp',
#  'BMC_Pediatr_2011_Jan_14_11_5.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2009_Nov_17_9_45.nxml.txt.nlp',
#  'BMC_Biol_2008_May_14_6_20.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Aug_28_10_270.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Feb_20_10_65.nxml.txt.nlp',
#  'BMC_Public_Health_2006_Jun_5_6_143.nxml.txt.nlp',
#  'BMC_Genomics_2013_Aug_16_14_557.nxml.txt.nlp',
#  'BMC_Biol_2005_May_12_3_13.nxml.txt.nlp',
#  'BMC_Gastroenterol_2007_Sep_23_7_37.nxml.txt.nlp',
#  'BMC_Med_Imaging_2003_Jul_22_3_1.nxml.txt.nlp',
#  'BMC_Genet_2005_Apr_8_6_18.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2014_Jun_17_14_264.nxml.txt.nlp',
#  'BMC_Plant_Biol_2010_Apr_19_10_70.nxml.txt.nlp',
#  'BMC_Pediatr_2014_Apr_22_14_108.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2011_Mar_31_11_35.nxml.txt.nlp',
#  'BMC_Cancer_2012_Aug_23_12_364.nxml.txt.nlp',
#  'BMC_Physiol_2005_Dec_20_5_18.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P29.nxml.txt.nlp',
#  'BMC_Med_Genet_2012_Apr_5_13_25.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_May_23_8_159.nxml.txt.nlp',
#  'BMC_Med_Genet_2010_Nov_30_11_168.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2005_Feb_15_5_3.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2009_Jan_21_9_14.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Aug_11_12_336.nxml.txt.nlp',
#  'BMC_Res_Notes_2013_Jan_5_6_8.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2010_Nov_26_10_318.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2010_May_20_10_21.nxml.txt.nlp',
#  'BMC_Evol_Biol_2007_Nov_8_7_215.nxml.txt.nlp',
#  'BMC_Surg_2013_Oct_8_13(Suppl_2)_S20.nxml.txt.nlp',
#  'BMC_Proc_2013_Apr_4_7(Suppl_2)_P31.nxml.txt.nlp',
#  'BMC_Neurosci_2008_Feb_26_9_29.nxml.txt.nlp',
#  'BMC_Med_Genet_2007_Jun_11_8_32.nxml.txt.nlp',
#  'BMC_Cancer_2011_Oct_19_11_451.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2012_Oct_30_12_373.nxml.txt.nlp',
#  'BMC_Evol_Biol_2008_May_22_8_158.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jul_23_11(Suppl_4)_O1.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2009_Jun_29_9_45.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Jul_19_13_185.nxml.txt.nlp',
#  'BMC_Genomics_2006_Nov_6_7_284.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_Oct_14_10_333.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2009_Oct_6_9_67.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Feb_25_9_121.nxml.txt.nlp',
#  'BMC_Urol_2005_Nov_22_5_14.nxml.txt.nlp',
#  'BMC_Palliat_Care_2011_Jul_9_10_12.nxml.txt.nlp',
#  'BMC_Infect_Dis_2005_Jul_6_5_53.nxml.txt.nlp',
#  'BMC_Endocr_Disord_2013_Jun_3_13_18.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Mar_22_11_149.nxml.txt.nlp',
#  'BMC_Proc_2012_Jun_1_6(Suppl_3)_P31.nxml.txt.nlp',
#  'BMC_Biol_2012_Dec_3_10_97.nxml.txt.nlp',
#  'BMC_Public_Health_2010_Apr_26_10_207.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Oct_15_14(Suppl_15)_S10.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2014_Apr_9_14_46.nxml.txt.nlp',
#  'BMC_Nephrol_2011_Oct_3_12_51.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2008_Jun_25_8_138.nxml.txt.nlp',
#  'BMC_Public_Health_2007_Jul_17_7_158.nxml.txt.nlp',
#  'BMC_Genomics_2014_Aug_26_15(1)_715.nxml.txt.nlp',
#  'BMC_Struct_Biol_2009_Mar_26_9_18.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Jan_30_13_25.nxml.txt.nlp',
#  'BMC_Pediatr_2013_Sep_3_13_133.nxml.txt.nlp',
#  'BMC_Nephrol_2014_Apr_3_15_55.nxml.txt.nlp',
#  'BMC_Bioinformatics_2008_Dec_5_9_522.nxml.txt.nlp',
#  'BMC_Public_Health_2011_May_23_11_370.nxml.txt.nlp',
#  'BMC_Cardiovasc_Disord_2010_Jun_17_10_29.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2013_Jun_26_13_234.nxml.txt.nlp',
#  'BMC_Biol_2010_Dec_22_8_151.nxml.txt.nlp',
#  'BMC_Cancer_2013_Nov_25_13_558.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jun_18_10_302.nxml.txt.nlp',
#  'BMC_Cancer_2009_Apr_7_9_105.nxml.txt.nlp',
#  'BMC_Genomics_2012_Dec_7_13(Suppl_7)_S28.nxml.txt.nlp',
#  'BMC_Pharmacol_2011_Aug_1_11(Suppl_1)_P8.nxml.txt.nlp',
#  'BMC_Genomics_2011_Feb_4_12_97.nxml.txt.nlp',
#  'BMC_Genomics_2007_Oct_10_8_366.nxml.txt.nlp',
#  'BMC_Genomics_2014_Apr_2_15(Suppl_2)_P48.nxml.txt.nlp',
#  'BMC_Pulm_Med_2012_Feb_20_12_6.nxml.txt.nlp',
#  'BMC_Clin_Pathol_2007_Aug_3_7_7.nxml.txt.nlp',
#  'BMC_Bioinformatics_2006_Jan_18_7_25.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_May_4_12(Suppl_1)_P53.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2003_Jul_21_3_14.nxml.txt.nlp',
#  'BMC_Neurol_2010_Jan_29_10_11.nxml.txt.nlp',
#  'BMC_Genomics_2014_Oct_17_15(Suppl_6)_S17.nxml.txt.nlp',
#  'BMC_Surg_2012_Apr_10_12_6.nxml.txt.nlp',
#  'BMC_Genomics_2009_Dec_31_10_645.nxml.txt.nlp',
#  'BMC_Gastroenterol_2014_May_30_14_102.nxml.txt.nlp',
#  'BMC_Nephrol_2014_May_19_15_80.nxml.txt.nlp',
#  'BMC_Genomics_2012_Feb_15_13_76.nxml.txt.nlp',
#  'BMC_Med_Inform_Decis_Mak_2013_Nov_30_13_130.nxml.txt.nlp',
#  'BMC_Res_Notes_2010_Aug_31_3_233.nxml.txt.nlp',
#  'BMC_Bioinformatics_2009_May_28_10_163.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_O2.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Dec_28_11_349.nxml.txt.nlp',
#  'BMC_Geriatr_2013_Dec_6_13_131.nxml.txt.nlp',
#  'BMC_Res_Notes_2012_Jul_10_5_349.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Nov_4_13_302.nxml.txt.nlp',
#  'BMC_Neurol_2013_Jul_9_13_77.nxml.txt.nlp',
#  'BMC_Genet_2005_Nov_27_6_55.nxml.txt.nlp',
#  'BMC_Cancer_2010_Oct_9_10_542.nxml.txt.nlp',
#  'BMC_Med_Ethics_2010_Jun_13_11_10.nxml.txt.nlp',
#  'BMC_Public_Health_2010_Apr_8_10_182.nxml.txt.nlp',
#  'BMC_Infect_Dis_2009_Dec_31_9_217.nxml.txt.nlp',
#  'BMC_Ear_Nose_Throat_Disord_2006_May_30_6_11.nxml.txt.nlp',
#  'BMC_Proc_2014_Jun_17_8(Suppl_1)_S97.nxml.txt.nlp',
#  'BMC_Genomics_2002_May_3_3_11.nxml.txt.nlp',
#  'BMC_Bioinformatics_2013_Apr_22_14(Suppl_7)_S10.nxml.txt.nlp',
#  'BMC_Public_Health_2011_May_26_11_391.nxml.txt.nlp',
#  'BMC_Mol_Biol_2008_Oct_24_9_93.nxml.txt.nlp',
#  'BMC_Plant_Biol_2012_Jul_26_12_117.nxml.txt.nlp',
#  'BMC_Genomics_2010_Jun_9_11_364.nxml.txt.nlp',
#  'BMC_Proc_2014_Oct_1_8(Suppl_4)_P42.nxml.txt.nlp',
#  'BMC_Evol_Biol_2007_Sep_27_7_177.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2014_Mar_28_15_109.nxml.txt.nlp',
#  'BMC_Bioinformatics_2010_Jan_5_11_7.nxml.txt.nlp',
#  'BMC_Res_Notes_2012_Dec_27_5_698.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2008_Jul_17_8_150.nxml.txt.nlp',
#  'BMC_Med_Educ_2005_Mar_7_5_9.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2013_Nov_8_14_318.nxml.txt.nlp',
#  'BMC_Res_Notes_2012_Aug_28_5_464.nxml.txt.nlp',
#  'BMC_Dev_Biol_2008_Oct_23_8_102.nxml.txt.nlp',
#  'BMC_Med_Educ_2008_May_23_8_32.nxml.txt.nlp',
#  'BMC_Med_Genet_2012_Mar_22_13_19.nxml.txt.nlp',
#  'BMC_Res_Notes_2014_Sep_18_7(1)_659.nxml.txt.nlp',
#  'BMC_Cancer_2011_Sep_29_11_418.nxml.txt.nlp',
#  'BMC_Infect_Dis_2012_Jul_12_12_155.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2013_Dec_12_13_355.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2006_Dec_11_6_56.nxml.txt.nlp',
#  'BMC_Genomics_2012_Dec_7_13(Suppl_7)_S3.nxml.txt.nlp',
#  'BMC_Evol_Biol_2014_Nov_30_14(1)_235.nxml.txt.nlp',
#  'BMC_Cancer_2011_Mar_9_11_94.nxml.txt.nlp',
#  'BMC_Cancer_2009_Aug_17_9_284.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2008_Apr_9_9_42.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2007_Oct_3_7_160.nxml.txt.nlp',
#  'BMC_Genomics_2011_Jan_31_12_89.nxml.txt.nlp',
#  'BMC_Health_Serv_Res_2011_Jul_5_11_157.nxml.txt.nlp',
#  'BMC_Proc_2011_Jan_10_5(Suppl_1)_P21.nxml.txt.nlp',
#  'BMC_Pregnancy_Childbirth_2012_Aug_9_12_81.nxml.txt.nlp',
#  'BMC_Microbiol_2008_Nov_24_8_203.nxml.txt.nlp',
#  'BMC_Fam_Pract_2009_Feb_7_10_12.nxml.txt.nlp',
#  'BMC_Proc_2011_Jun_29_5(Suppl_6)_P323.nxml.txt.nlp',
#  'BMC_Genet_2011_May_13_12_44.nxml.txt.nlp',
#  'BMC_Genomics_2014_Nov_21_15(1)_1009.nxml.txt.nlp',
#  'BMC_Public_Health_2012_May_14_12_353.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2004_Mar_16_5_8.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P312.nxml.txt.nlp',
#  'BMC_Cancer_2012_Jul_16_12_291.nxml.txt.nlp',
#  'BMC_Cancer_2010_Jul_1_10_345.nxml.txt.nlp',
#  'BMC_Syst_Biol_2009_Oct_8_3_101.nxml.txt.nlp',
#  'BMC_Complement_Altern_Med_2012_Jun_12_12(Suppl_1)_P136.nxml.txt.nlp',
#  'BMC_Biochem_2006_Apr_16_7_12.nxml.txt.nlp',
#  'BMC_Vet_Res_2012_Jul_20_8_116.nxml.txt.nlp',
#  'BMC_Med_Res_Methodol_2013_Sep_30_13_120.nxml.txt.nlp',
#  'BMC_Med_Imaging_2012_Dec_21_12_36.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Jul_14_12_285.nxml.txt.nlp',
#  'BMC_Genomics_2007_Aug_7_8_267.nxml.txt.nlp',
#  'BMC_Musculoskelet_Disord_2014_May_22_15_169.nxml.txt.nlp',
#  'BMC_Surg_2006_Oct_23_6_12.nxml.txt.nlp',
#  'BMC_Fam_Pract_2011_May_31_12_42.nxml.txt.nlp',
#  'BMC_Surg_2008_Nov_26_8_21.nxml.txt.nlp',
#  'BMC_Infect_Dis_2014_May_23_14(Suppl_2)_P43.nxml.txt.nlp',
#  'BMC_Bioinformatics_2011_Jul_28_12(Suppl_6)_S2.nxml.txt.nlp',
#  'BMC_Biol_2013_Sep_4_11_98.nxml.txt.nlp',
#  ...]

# %% [markdown]
# Now the sentences need to be tagged to their appropriate section and concatenated into one string per section per document.
#
# The sentences are assigned a section by whichever section they are closest to (that is less than their sentence number). For example, if introduction had sentence number 5 and methods had sentence number 25, sentence number 20 would be assigned to introduction.
#
# This is done for each sentence in each document and joined by spaces into a one string per section per document. Finally, only the documents that contain an introduction, discussion, and conclusion are kept and put into the validDocsDict dictionary

# %%
documentDict = defaultdict(list)
docPartsDict = defaultdict(lambda : defaultdict(list))
docPartsCombinedDict = defaultdict(dict)

for item in sentObjList:
    documentDict[item.document].append(item)
    
for document in documentDict.keys():
    docSentList = documentDict[document]
    introNum = int(headingsDict[document].get("introduction", -1))
    methoNum = int(headingsDict[document].get("methods", -1))
    resultNum = int(headingsDict[document].get("results", -1))
    discussNum = int(headingsDict[document].get("discussion", -1))
    conclusionNum = int(headingsDict[document].get("conclusion", -1))
    refNum = int(headingsDict[document].get("references", -1))

    for sent in docSentList:
        label = "noSection"
        dist = int(sent.sentenceNumber)
        sentNumber = int(sent.sentenceNumber)
        
        if dist > sentNumber - introNum and sentNumber - introNum > 0:
            label = "introduction"
            dist = sentNumber - introNum
        if dist > sentNumber - methoNum and sentNumber - methoNum > 0:
            label = "methods"
            dist = sentNumber - methoNum
        if dist > sentNumber - resultNum and sentNumber - resultNum > 0:
            label = "results"
            dist = sentNumber - resultNum
        if dist > sentNumber - discussNum and sentNumber - discussNum > 0:
            label = "discussion"
            dist = sentNumber - discussNum
        if dist > sentNumber - conclusionNum and sentNumber - conclusionNum > 0:
            label = "conclusion"
            dist = sentNumber - conclusionNum
        if dist > sentNumber - refNum and sentNumber - refNum > 0:
            label = "references"
            dist = sentNumber - refNum
        if sent.sentence.strip().lower() not in ["introduction", "methods", "results", "discussion", "conclusion", "references"]:
            docPartsDict[document][label].append(sent)
    
    for x in docPartsDict[document].keys():
        docPartsCombinedDict[document][x] = " ".join(y.sentence for y in sorted(docPartsDict[document][x], key=lambda z: z.sentenceNumber))

validDocsDict = defaultdict(dict)

for doc in docPartsCombinedDict.keys():
    tempKeys = docPartsCombinedDict[doc].keys()
    if 'introduction' in tempKeys and 'discussion' in tempKeys and 'conclusion' in tempKeys:
        validDocsDict[doc] = docPartsCombinedDict[doc]

print(str(len(docPartsCombinedDict.keys())))
print(str(len(validDocsDict.keys())))
# Out:
# 2189
# 800

# %% [markdown]
# Take the valid documents in the validDocsDict and output to a pickle file with the key part_docid with the part being introduction, methods, etc. and the docid allowing for document tracking.

# %%
outputDict = dict()
for doc in validDocsDict.keys():
    for part in validDocsDict[doc].keys():
        outputDict[part + "_" + doc] = validDocsDict[doc][part]

pickle.dump(outputDict, open("TestDocsPub_kimtest.p", "wb"))
