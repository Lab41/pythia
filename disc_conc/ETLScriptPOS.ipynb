# %% [markdown]
# # Data Processing for Topic Model Test including Parts of Speech
#
# Getting the data from the repository...don't run unless you don't have the data!
#
# !apt-get -y install curl
#
# !curl -o BioMedSent/BioMedSentences.tar.zip http://i.stanford.edu/hazy/opendata/bmc/bmc_full_dddb_20150927_9651bf4a468cefcea30911050c2ca6db.tar.bzip2
#
# http://i.stanford.edu/hazy/opendata/pmc/pmc_dddb_full_20150927_3b20db570e2cb90ab81c5c6f63babc91.tar.bzip2

# %% [markdown]
# # Import Data
#
# This section defines the Sentence object used when importing and saving the data. Grab the files in a directory and process a subset of them.

# %%
#Import Statements
import string
import os
import pickle
from collections import defaultdict
from multiprocessing import Pool

#Sentence object definition for data import and processing 
class Sentence:
    def __init__(self, document, sentenceNumber, wordList, lemmaList, posList):
        self.document = document
        self.sentenceNumber = sentenceNumber
        self.wordList = wordList
        self.lemmaList = lemmaList
        self.posList = posList
        self.sentence = " ".join([word for word in wordList if word not in string.punctuation])
        self.lemmaSent = " ".join([word for word in lemmaList if word not in string.punctuation])

#Get the files we want to process and put them into a list of lists called sentList
fileList = os.listdir("../PubMed/pmc_dddb_full")
sentList = []
fileList.sort()
for n in range(35, 36):
    f = open("../PubMed/pmc_dddb_full/" + fileList[n], 'r')
    for line in f:
        sentList.append(line.split('\t'))

len(sentList)
# Out:
# 1869698

# %% [markdown]
# Now that we have all of the sentences in a list of lists grab the first element of each sentence list (the document id) and add that to a docList. Make this docList a set so we have the number of unique documents.

# %%
docList = []
for thing in sentList:
    docList.append(thing[0])

len(set(docList))
# Out:
# 9981

# %% [markdown]
# # Process Data
#
# Define the processSent function for use by the multiprocessing part of the code. This function takes off some of the structure of parts of the data (removing the {,}, and ") and defines the Sentence object with all the appropriate parts.
#
# We then use 14 cores (if available) for the Pool object and apply the processSent function to every sentence.

# %%
sentObjList = []
def processSent(item):
    wordList = item[3].replace('"',"").lstrip("{").rstrip("}").split(",")
    wordList = filter(None, wordList)
    posList = item[4].split(",")
    lemmaList = item[6].replace('"',"").lstrip("{").rstrip("}").split(",")
    lemmaList = filter(None, lemmaList)
    return Sentence(item[0], item[1], wordList, lemmaList, posList)

po = Pool(16)
results = [po.apply_async(processSent, args = (sent,)) for sent in sentList]
po.close()
po.join()
output = [p.get() for p in results]
sentObjList = output
sentObjList[7].lemmaSent
# Out:
# 'ozone concentration increase will decrease yield by 5 per cent or more'

# %% [markdown]
# Now that the sentences are processed, we need to find which sections these sentences should be atributed. For most of these papers, section headers are one word sentences. We are looking for common section headers and saving the sentence numbers for that section in that document.

# %%
headingsDict = defaultdict(dict)

for sent in sentObjList:
    if len(sent.wordList) == 1:
        #print(sent.wordList)
        word = string.upper(sent.wordList[0]).strip()
        if word == 'INTRODUCTION' or word == 'BACKGROUND':
            headingsDict[sent.document]["introduction"] = sent.sentenceNumber
        elif word == 'METHODS':
            headingsDict[sent.document]["methods"] = sent.sentenceNumber
        elif word == 'RESULTS':
            headingsDict[sent.document]["results"] = sent.sentenceNumber
        elif word == 'DISCUSSION':
            headingsDict[sent.document]["discussion"] = sent.sentenceNumber
        elif word == 'CONCLUSION':
            headingsDict[sent.document]["conclusion"] = sent.sentenceNumber
        elif word == 'REFERENCES':
            headingsDict[sent.document]["references"] = sent.sentenceNumber
        

headingsDict.keys()
# Out:
# ['Sensors_(Basel)_2012_May_25_12(6)_6869-6892.nxml.txt.nlp',
#  'Pharm_Pract_(Granada)_2006_Dec_12_Oct-Dec_4(4)_191-194.nxml.txt.nlp',
#  'Soc_Indic_Res_2013_Nov_11_114(3)_1243-1257.nxml.txt.nlp',
#  'Sensors_(Basel)_2013_Jan_15_13(1)_918-937.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Aug_10_69(Pt_9)_m483-m484.nxml.txt.nlp',
#  'Hum_Resour_Health_2011_Feb_17_9_6.nxml.txt.nlp',
#  'Autoimmune_Dis_2011_May_5_2011_189585.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2003_Jan_9(1)_123-126.nxml.txt.nlp',
#  'Food_Chem_2012_Nov_1_135-334(1)_80-87.nxml.txt.nlp',
#  'Genome_Med_2010_Jan_15_2(1)_2.nxml.txt.nlp',
#  'Environ_Health_Perspect_2008_Nov_26_116(11)_1541-1546.nxml.txt.nlp',
#  'J_Invest_Dermatol_2011_Aug_12_131(8)_1615-1621.nxml.txt.nlp',
#  'Cancer_Cell_Int_2012_Dec_15_12_52.nxml.txt.nlp',
#  'Ann_Indian_Acad_Neurol_2008_Jul-Sep_11(3)_199.nxml.txt.nlp',
#  'Indian_J_Ophthalmol_2010_Jul-Aug_58(4)_345b.nxml.txt.nlp',
#  'Glia_2014_Jun_3_62(6)_964-970.nxml.txt.nlp',
#  'Pharmacogn_Rev_2012_Jul-Dec_6(12)_91-99.nxml.txt.nlp',
#  'J_Neurol_Surg_Rep_2014_Aug_24_75(1)_e129-e132.nxml.txt.nlp',
#  'Arch_Med_Sci_2010_Dec_29_6(6)_956-963.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2014_Dec_20(12)_2182-2184.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Nov_17_66(Pt_12)_o3193.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2010_Apr_1_12(2)_R59.nxml.txt.nlp',
#  'Nat_Commun_2014_Dec_15_5_5813.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jul_8_65(Pt_8)_o1802-o1803.nxml.txt.nlp',
#  'Sensors_(Basel)_2013_May_3_13(5)_5749-5756.nxml.txt.nlp',
#  'Crit_Care_2013_Mar_19_17(Suppl_2)_P464.nxml.txt.nlp',
#  'Mol_Cytogenet_2014_Jan_28_7_10.nxml.txt.nlp',
#  'Front_Behav_Neurosci_2014_May_7_8_153.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2012_Nov_15_14(11)_743-745.nxml.txt.nlp',
#  'Oncotarget_2013_May_31_4(5)_651-664.nxml.txt.nlp',
#  'Archaea_2011_Oct_10_2011_693253.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Mar_23_67(Pt_4)_o960.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Apr_24_2014_915797.nxml.txt.nlp',
#  'Int_J_Biomater_2012_Jul_12_2012_319290.nxml.txt.nlp',
#  'Drugs_R_D_2012_Sep_18_12(3)_121-126.nxml.txt.nlp',
#  'Int_J_Environ_Res_Public_Health_2013_Dec_17_10(12)_7257-7271.nxml.txt.nlp',
#  'Front_Neuroinformatics_2009_Jan_8_2_8.nxml.txt.nlp',
#  'Curr_Rev_Musculoskelet_Med_2007_Nov_6_1(1)_65-68.nxml.txt.nlp',
#  'Neural_Regen_Res_2012_Sep_25_7(27)_2123-2129.nxml.txt.nlp',
#  'Breast_Cancer_Res_2007_Jul_30_9(4)_R49.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2012_Aug_17_14(4)_R190.nxml.txt.nlp',
#  'Indian_J_Community_Med_2010_Jan_35(1)_94-99.nxml.txt.nlp',
#  'Clin_Interv_Aging_2011_Feb_22_6_53-59.nxml.txt.nlp',
#  'Indian_J_Med_Res_2013_Apr_137(4)_659-668.nxml.txt.nlp',
#  'Turk_J_Haematol_2014_Sep_5_31(3)_226-230.nxml.txt.nlp',
#  'Cases_J_2009_Jul_1_2_6157.nxml.txt.nlp',
#  'Zookeys_2015_Jan_19_(472)_103-116.nxml.txt.nlp',
#  'Indian_J_Occup_Environ_Med_2010_Aug_14(2)_45-48.nxml.txt.nlp',
#  'Community_Eye_Health_2012_25(79-80)_54.nxml.txt.nlp',
#  'J_Addict_2014_Aug_26_2014_352835.nxml.txt.nlp',
#  'Br_J_Sports_Med_2013_Dec_47(Suppl_1)_i114-i120.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2012_Oct_18(10)_1694-1696.nxml.txt.nlp',
#  'Tanaffos_2013_12(1)_42-56.nxml.txt.nlp',
#  'Arch_Med_Sci_2014_Feb_24_10(1)_110-116.nxml.txt.nlp',
#  'Can_J_Infect_Dis_Med_Microbiol_2014_May-Jun_25(3)_173-175.nxml.txt.nlp',
#  'Clin_Pract_2012_Apr_13_2(2)_e46.nxml.txt.nlp',
#  'Br_J_Cancer_2009_Oct_20_101(8)_1351-1356.nxml.txt.nlp',
#  'BMJ_2010_Dec_1_341_c6387.nxml.txt.nlp',
#  'eLife_2014_Apr_15_3_e01741.nxml.txt.nlp',
#  'Antimicrob_Resist_Infect_Control_2013_Jun_20_2(Suppl_1)_P171.nxml.txt.nlp',
#  'Amyotroph_Lateral_Scler_2012_Jun_28_13(4)_347-350.nxml.txt.nlp',
#  'Comput_Math_Methods_Med_2013_Jul_10_2013_579214.nxml.txt.nlp',
#  'Adv_Ther_2013_Sep_27_30(9)_819-833.nxml.txt.nlp',
#  'Food_Nutr_Res_2009_Feb_20_53_10_3402_fnr_v53i0_1889.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2010_Oct_16(10)_1644-1645.nxml.txt.nlp',
#  'Cell_Cycle_2012_Apr_15_11(8)_1485.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2012_Feb_1_14(2)_86-95.nxml.txt.nlp',
#  'J_Physiol_2009_Jul_15_587(Pt_14)_3493-3503.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2011_Dec_17(12)_2287-2293.nxml.txt.nlp',
#  'Ann_R_Coll_Surg_Engl_2013_Jan_95(1)_82a.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_May_26_66(Pt_6)_o1469.nxml.txt.nlp',
#  'Clin_Ophthalmol_2014_Oct_29_8_2171-2175.nxml.txt.nlp',
#  'Basic_Res_Cardiol_2013_Jan_28_108(1)_317.nxml.txt.nlp',
#  'Indian_J_Ophthalmol_2008_Jul-Aug_56(4)_307-312.nxml.txt.nlp',
#  'Genome_Biol_2011_Sep_19_12(Suppl_1)_P16.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2011_Mar_12_39(6)_2188-2209.nxml.txt.nlp',
#  'Surg_Endosc_2012_Mar_30_26(3)_632-638.nxml.txt.nlp',
#  'Breast_Cancer_Res_2012_Jan_17_14(1)_R13.nxml.txt.nlp',
#  'Brief_Bioinform_2013_Mar_19_14(2)_225-237.nxml.txt.nlp',
#  'Case_Rep_Med_2011_Aug_4_2011_861094.nxml.txt.nlp',
#  'Case_Rep_Oncol_2013_Jun_22_6(2)_331-338.nxml.txt.nlp',
#  'Case_Rep_Obstet_Gynecol_2013_Jun_11_2013_860505.nxml.txt.nlp',
#  'N_Am_J_Med_Sci_2014_Aug_6(8)_383-390.nxml.txt.nlp',
#  'Dent_Mater_2014_Jan_30(1)_50-61.nxml.txt.nlp',
#  'Cancers_(Basel)_2013_Jul_5_5(3)_875-889.nxml.txt.nlp',
#  'Chem_Cent_J_2013_Oct_26_7_170.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Sep_22_68(Pt_10)_o2963.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jul_18_65(Pt_8)_m955-m956.nxml.txt.nlp',
#  'Colloid_Polym_Sci_2014_May_23_292(8)_1853-1862.nxml.txt.nlp',
#  'Cardiol_Res_Pract_2011_Jan_20_2011_924945.nxml.txt.nlp',
#  'Environ_Health_Perspect_2005_Jan_30_113(1)_17-24.nxml.txt.nlp',
#  'J_Biomed_Sci_2014_Nov_18_21(1)_99.nxml.txt.nlp',
#  'Vet_Res_Forum_2014_Winter_5(1)_65-68.nxml.txt.nlp',
#  'Cell_Cycle_2012_Jun_15_11(12)_2225-2226.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Jan_6_2014_152659.nxml.txt.nlp',
#  'Open_Biol_2014_Jun_4(6)_140026.nxml.txt.nlp',
#  'ScientificWorldJournal_2013_Mar_21_2013_947018.nxml.txt.nlp',
#  'Int_J_Biomed_Imaging_2013_Nov_27_2013_201735.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2010_Nov_65(11)_1133-1137.nxml.txt.nlp',
#  'Sensors_(Basel)_2013_May_7_13(5)_5857-5869.nxml.txt.nlp',
#  'Infect_Dis_Rep_2012_Feb_17_4(1)_e4.nxml.txt.nlp',
#  'Diabetes_Care_2011_Apr_21_34(4)_838-844.nxml.txt.nlp',
#  'Exp_Ther_Med_2013_Jan_19_5(1)_175-180.nxml.txt.nlp',
#  'Acta_Vet_Scand_2008_Jun_13_50(1)_17.nxml.txt.nlp',
#  'Sensors_(Basel)_2013_Mar_4_13(3)_3077-3091.nxml.txt.nlp',
#  'Pan_Afr_Med_J_2014_Feb_3_17_84.nxml.txt.nlp',
#  'Oxid_Med_Cell_Longev_2013_Mar_5_2013_264935.nxml.txt.nlp',
#  'Br_J_Cancer_2010_Mar_2_102(5)_803-809.nxml.txt.nlp',
#  'Aging_Cell_2008_Oct_7(5)_622-629.nxml.txt.nlp',
#  'Evid_Based_Complement_Alternat_Med_2014_Nov_25_2014_836392.nxml.txt.nlp',
#  'Mol_Cancer_2014_Feb_25_13_38.nxml.txt.nlp',
#  'Indian_J_Radiol_Imaging_2010_Feb_20(1)_72-74.nxml.txt.nlp',
#  'Sensors_(Basel)_2012_Dec_6_12(12)_16771-16784.nxml.txt.nlp',
#  'J_Biomed_Sci_2013_Jan_25_20(1)_5.nxml.txt.nlp',
#  'J_Epilepsy_Res_2012_Mar_30_2(1)_21-24.nxml.txt.nlp',
#  'Chiropr_Man_Therap_2011_Oct_4_19_25.nxml.txt.nlp',
#  'Oncotarget_2010_Oct_12_1(7)_674-684.nxml.txt.nlp',
#  'J_Cardiothorac_Surg_2013_Apr_18_8_100.nxml.txt.nlp',
#  'Neural_Regen_Res_2013_May_25_8(15)_1349-1359.nxml.txt.nlp',
#  'Oncoimmunology_2013_Aug_1_2(8)_e25594.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Sep_20_64(Pt_10)_o1974.nxml.txt.nlp',
#  'Front_Neuroinform_2013_Feb_14_7_2.nxml.txt.nlp',
#  'Case_Rep_Dent_2013_Aug_6_2013_138248.nxml.txt.nlp',
#  'Ann_Med_Health_Sci_Res_2014_May-Jun_4(3)_388-392.nxml.txt.nlp',
#  'J_Surg_Case_Rep_2013_Dec_17_2013(12)_rjt108.nxml.txt.nlp',
#  'Clin_Med_Oncol_2009_Jun_15_3_71-75.nxml.txt.nlp',
#  'Eur_J_Dent_2011_Apr_5(2)_163-167.nxml.txt.nlp',
#  'J_Med_Case_Reports_2011_Jan_6_5_3.nxml.txt.nlp',
#  'Surg_Endosc_2010_Dec_13_24(12)_3102-3108.nxml.txt.nlp',
#  'Indian_J_Endocrinol_Metab_2013_Nov-Dec_17(6)_1117-1119.nxml.txt.nlp',
#  'Chiropr_Osteopat_2010_Sep_8_18_26.nxml.txt.nlp',
#  'Cell_Cycle_2012_Jun_1_11(11)_2114-2121.nxml.txt.nlp',
#  'Case_Rep_Surg_2013_Feb_21_2013_305039.nxml.txt.nlp',
#  'Ann_Pediatr_Cardiol_2010_Jan-Jun_3(1)_31-34.nxml.txt.nlp',
#  'Virol_J_2009_Dec_4_6_215.nxml.txt.nlp',
#  'Case_Rep_Endocrinol_2014_Dec_16_2014_987272.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Apr_13_67(Pt_5)_m563.nxml.txt.nlp',
#  'Front_Neurosci_2009_May_29_3_46.nxml.txt.nlp',
#  'Global_Health_2009_Oct_29_5_14.nxml.txt.nlp',
#  'J_Int_Soc_Sports_Nutr_2008_Sep_17_5(Suppl_1)_P9.nxml.txt.nlp',
#  'Int_Arch_Occup_Environ_Health_2010_Apr_15_83(4)_381-388.nxml.txt.nlp',
#  'Case_Rep_Radiol_2011_Jul_7_2011_904017.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jul_13_69(Pt_8)_o1246.nxml.txt.nlp',
#  'Clin_Ophthalmol_2012_Dec_20_6_2109-2117.nxml.txt.nlp',
#  'Evid_Based_Complement_Alternat_Med_2014_Jul_23_2014_273878.nxml.txt.nlp',
#  'J_Arthropod_Borne_Dis_2013_Aug_31_7(2)_188-193.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2013_Feb_17_41(3)_e43.nxml.txt.nlp',
#  'Indian_J_Pharmacol_2008_Mar-Apr_40(2)_64-68.nxml.txt.nlp',
#  'Case_Rep_Gastroenterol_2011_Jul_21_5(2)_404-410.nxml.txt.nlp',
#  'Head_Face_Med_2009_Aug_6_5_16.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2005_Jul_11(7)_1009-1015.nxml.txt.nlp',
#  'Braz_J_Microbiol_2012_Jun_1_Jan-Mar_43(1)_215-223.nxml.txt.nlp',
#  'Hum_Resour_Health_2014_Feb_17_12_11.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Mar_6_69(Pt_4)_o500.nxml.txt.nlp',
#  'Braz_J_Microbiol_2011_Dec_1_Oct-Dec_42(4)_1265-1268.nxml.txt.nlp',
#  'Anat_Res_Int_2014_Sep_3_2014_168614.nxml.txt.nlp',
#  'ScientificWorldJournal_2014_Mar_19_2014_206843.nxml.txt.nlp',
#  'Diabetes_Care_2011_Dec_14_34(12)_e184.nxml.txt.nlp',
#  'Eur_Arch_Psychiatry_Clin_Neurosci_2012_Dec_21_262(8)_657-666.nxml.txt.nlp',
#  'Aging_(Albany_NY)_2011_Mar_28_3(4)_438-443.nxml.txt.nlp',
#  'Front_Oncol_2014_Mar_31_4_65.nxml.txt.nlp',
#  'Indian_J_Orthop_2009_Apr-Jun_43(2)_132-140.nxml.txt.nlp',
#  'Ind_Psychiatry_J_2011_Jan-Jun_20(1)_56-57.nxml.txt.nlp',
#  'J_Korean_Neurosurg_Soc_2014_Jul_31_56(1)_42-47.nxml.txt.nlp',
#  'Diabetes_Care_2010_Sep_2_33(9)_2110-2112.nxml.txt.nlp',
#  'Clin_Ophthalmol_2013_Sep_19_7_1849-1858.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2005_Jan_11_7(2)_R285-R290.nxml.txt.nlp',
#  'Bioinformatics_2009_Aug_15_25(16)_2080-2081.nxml.txt.nlp',
#  'Indian_J_Psychol_Med_2014_Apr-Jun_36(2)_153-157.nxml.txt.nlp',
#  'Indian_J_Orthop_2010_Oct-Dec_44(4)_424-427.nxml.txt.nlp',
#  'Front_Immunol_2013_Oct_28_4_346.nxml.txt.nlp',
#  'BMJ_Open_2014_Feb_21_4(2)_e004226.nxml.txt.nlp',
#  'Mol_Cytogenet_2014_Jan_21_7(Suppl_1)_P23.nxml.txt.nlp',
#  'Int_J_Crit_Illn_Inj_Sci_2011_Jan-Jun_1(1)_51-56.nxml.txt.nlp',
#  'Environ_Health_Perspect_2011_Sep_29_119(9)_1345-1349.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2013_May_8_41(10)_5164-5174.nxml.txt.nlp',
#  'Acta_Pharmacol_Sin_2011_Oct_22_32(10)_1215-1224.nxml.txt.nlp',
#  'Diabetologia_2008_Sep_28_51(9)_1694-1697.nxml.txt.nlp',
#  'Front_Oncol_2014_Aug_12_4_179.nxml.txt.nlp',
#  'Front_Neuroanat_2014_Nov_20_8_137.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2006_Jul_19_8(4)_R115.nxml.txt.nlp',
#  'Cancers_(Basel)_2010_Aug_18_2(3)_1602-1616.nxml.txt.nlp',
#  'BJOG_2007_Oct_114(10)_1191-1193.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Jul_10_66(Pt_8)_o1973-o1974.nxml.txt.nlp',
#  'Aging_(Albany_NY)_2009_Jul_14_1(7)_652-663.nxml.txt.nlp',
#  'Bioinformation_2010_Nov_27_5(6)_250-254.nxml.txt.nlp',
#  'Niger_Med_J_2013_Mar-Apr_54(2)_87-91.nxml.txt.nlp',
#  'Clin_Exp_Otorhinolaryngol_2009_Mar_26_2(1)_6-12.nxml.txt.nlp',
#  'Philos_Trans_R_Soc_Lond_B_Biol_Sci_2010_Jun_27_365(1548)_1953-1963.nxml.txt.nlp',
#  'Arthritis_Res_1999_Oct_14_1(1)_63-70.nxml.txt.nlp',
#  'Int_J_Nanomedicine_2012_Oct_8_7_5215-5234.nxml.txt.nlp',
#  'J_Youth_Adolesc_2014_Sep_9_43(10)_1595-1610.nxml.txt.nlp',
#  'Ophthalmol_Eye_Dis_2011_Jan_12_3_13-19.nxml.txt.nlp',
#  'Hematol_Rep_2012_Sep_4_4(3)_e16.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Jan_12_2014_736385.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2014_May_31_70(Pt_6)_o724.nxml.txt.nlp',
#  'Anal_Bioanal_Chem_2010_Aug_13_397(8)_3441-3455.nxml.txt.nlp',
#  'Adv_Prev_Med_2011_Sep_1_2011_298787.nxml.txt.nlp',
#  'Sci_Rep_2014_Dec_16_4_7506.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Sep_11_66(Pt_10)_o2535.nxml.txt.nlp',
#  'Pancreas_2014_Mar_11_43(2)_153-161.nxml.txt.nlp',
#  'Ann_Lab_Med_2013_Jul_24_33(4)_255-260.nxml.txt.nlp',
#  'Clin_Interv_Aging_2010_Nov_19_5_355-362.nxml.txt.nlp',
#  'AIDS_Res_Treat_2014_Oct_1_2014_237834.nxml.txt.nlp',
#  'Indian_J_Pharm_Sci_2012_Nov-Dec_74(6)_487-497.nxml.txt.nlp',
#  'Br_J_Cancer_2003_Jun_2_88(11)_1755-1762.nxml.txt.nlp',
#  'Case_Rep_Pediatr_2011_Sep_29_2011_564868.nxml.txt.nlp',
#  'Asia_Pac_Allergy_2013_Oct_31_3(4)_215-223.nxml.txt.nlp',
#  'Chem_Cent_J_2012_Nov_28_6_145.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2006_Aug_15_8(5)_R141.nxml.txt.nlp',
#  'World_Allergy_Organ_J_2012_Feb_17_5(Suppl_2)_S143c-S144.nxml.txt.nlp',
#  'Case_Rep_Dent_2011_Jul_6_2011_381382.nxml.txt.nlp',
#  'Curr_Heart_Fail_Rep_2010_Jun_28_7(2)_75-82.nxml.txt.nlp',
#  'J_Vet_Med_Sci_2014_Aug_8_76(8)_1111-1117.nxml.txt.nlp',
#  'Cancer_Res_Treat_2012_Mar_31_44(1)_32-36.nxml.txt.nlp',
#  'Bioinformation_2010_Sep_20_5(3)_136-140.nxml.txt.nlp',
#  'Glia_2012_Feb_2_60(2)_203-217.nxml.txt.nlp',
#  'Br_J_Cancer_2009_Oct_20_101(8)_1425-1432.nxml.txt.nlp',
#  'J_Cell_Biol_1999_Jan_25_144(2)_201-211.nxml.txt.nlp',
#  'Crit_Care_2001_Mar_2_5(Suppl_1)_P133.nxml.txt.nlp',
#  'Gut_Liver_2014_Mar_11_8(2)_117-130.nxml.txt.nlp',
#  'Online_J_Public_Health_Inform_2013_Apr_4_5(1)_e163.nxml.txt.nlp',
#  'Environ_Health_Perspect_2011_Aug_1_119(8)_a326-a327.nxml.txt.nlp',
#  'Anal_Bioanal_Chem_2010_Jul_30_397(5)_1955-1963.nxml.txt.nlp',
#  'Clin_Ophthalmol_2013_Sep_9_7_1787-1789.nxml.txt.nlp',
#  'Online_J_Public_Health_Inform_2013_Apr_4_5(1)_e106.nxml.txt.nlp',
#  'Environ_Health_Perspect_2008_Aug_31_116(8)_1085-1091.nxml.txt.nlp',
#  'Iran_J_Pharm_Res_2015_Winter_14(1)_167-175.nxml.txt.nlp',
#  'J_Korean_Med_Sci_2006_Apr_20_21(2)_265-271.nxml.txt.nlp',
#  'Hum_Mol_Genet_2011_Feb_15_20(4)_840-852.nxml.txt.nlp',
#  'Curr_Control_Trials_Cardiovasc_Med_2000_Jul_25_1(1)_9-14.nxml.txt.nlp',
#  'Acta_Pharmacol_Sin_2011_Jun_3_32(6)_685-692.nxml.txt.nlp',
#  'Gigascience_2014_May_28_3_7.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Nov_20_64(Pt_12)_o2374.nxml.txt.nlp',
#  'Arch_Osteoporos_2009_Dec_18_4(1-2)_1-8.nxml.txt.nlp',
#  'Int_J_Mol_Sci_2013_Apr_17_14(4)_8422-8436.nxml.txt.nlp',
#  'Oncoimmunology_2012_May_1_1(3)_375-376.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2012_Feb_1_14(Suppl_1)_O51.nxml.txt.nlp',
#  'Cerebrospinal_Fluid_Res_2009_Nov_27_6(Suppl_2)_S19.nxml.txt.nlp',
#  'Case_Rep_Med_2013_Mar_19_2013_604513.nxml.txt.nlp',
#  'Environ_Health_Perspect_2005_Mar_7_113(3)_266-271.nxml.txt.nlp',
#  'J_Gen_Intern_Med_2007_Nov_24_22(Suppl_2)_341-346.nxml.txt.nlp',
#  'Asian_J_Neurosurg_2010_Jan-Jun_5(1)_68-77.nxml.txt.nlp',
#  'Facts_Views_Vis_Obgyn_2011_3(2)_89-99.nxml.txt.nlp',
#  'J_Res_Med_Sci_2011_May_16(5)_707-711.nxml.txt.nlp',
#  'Case_Rep_Obstet_Gynecol_2013_May_2_2013_492754.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2005_Apr_22_33(7)_2332-2342.nxml.txt.nlp',
#  'Front_Physiol_2013_Jul_16_4_168.nxml.txt.nlp',
#  'Diabetes_2009_Mar_58(3)_652-662.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Sep_12_65(Pt_10)_m1208.nxml.txt.nlp',
#  'Acta_Pharmacol_Sin_2009_Oct_21_30(10)_1462-1470.nxml.txt.nlp',
#  'Exp_Ther_Med_2014_Dec_8_8(6)_1934-1938.nxml.txt.nlp',
#  'Iranian_J_Environ_Health_Sci_Eng_2013_Mar_1_10(1)_21.nxml.txt.nlp',
#  'J_Gen_Physiol_2000_Dec_1_116(6)_825-844.nxml.txt.nlp',
#  'ASN_Neuro_2013_Aug_29_5(4)_e00120.nxml.txt.nlp',
#  'Tech_Coloproctol_2011_Jun_3_15(2)_135-141.nxml.txt.nlp',
#  'Cases_J_2009_Jun_9_2_6894.nxml.txt.nlp',
#  'J_Immunother_Cancer_2013_Nov_7_1(Suppl_1)_P31.nxml.txt.nlp',
#  'J_Med_Case_Reports_2011_Sep_28_5_485.nxml.txt.nlp',
#  'Hum_Psychopharmacol_2008_Jan_23(1)_13-20.nxml.txt.nlp',
#  'Clinics_2008_Jun_63(3)_343-350.nxml.txt.nlp',
#  'Ann_Oncol_2011_May_6_22(5)_1189-1197.nxml.txt.nlp',
#  'Commun_Integr_Biol_2013_Jul_1_6(4)_e24511.nxml.txt.nlp',
#  'Ann_Surg_Oncol_2009_Dec_28_16(12)_3455-3462.nxml.txt.nlp',
#  'Anesth_Essays_Res_2012_Jan-Jun_6(1)_111.nxml.txt.nlp',
#  'J_Radiat_Res_2014_Nov_10_55(6)_1048-1055.nxml.txt.nlp',
#  'Hum_Genomics_2004_May_1_1(4)_247-254.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Jun_30_67(Pt_7)_o1836.nxml.txt.nlp',
#  'Bioinformation_2013_Jan_18_9(2)_94-100.nxml.txt.nlp',
#  'J_Cardiothorac_Surg_2013_Mar_7_8_39.nxml.txt.nlp',
#  'J_Surg_Case_Rep_2012_Jun_1_2012(6)_3.nxml.txt.nlp',
#  'Indian_J_Psychiatry_2012_Jan-Mar_54(1)_6-7.nxml.txt.nlp',
#  'Eur_Radiol_2011_Jul_2_21(7)_1535-1545.nxml.txt.nlp',
#  'Front_Neuroinformatics_2010_Dec_28_4_118.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2014_Jun_30_8_474.nxml.txt.nlp',
#  'Environ_Health_Perspect_2007_Oct_19_115(10)_1454-1459.nxml.txt.nlp',
#  'Oncol_Lett_2013_May_22_5(5)_1546-1548.nxml.txt.nlp',
#  'Indian_Dermatol_Online_J_2014_Nov_5(Suppl_1)_S44-S47.nxml.txt.nlp',
#  'Colomb_Med_(Cali)_43(2)_175-180.nxml.txt.nlp',
#  'N_Am_J_Med_Sci_2013_Jun_5(6)_367-370.nxml.txt.nlp',
#  'Indian_J_Dent_2014_Jul-Sep_5(3)_166-169.nxml.txt.nlp',
#  'Clin_Interv_Aging_2014_Sep_29_9_1645-1660.nxml.txt.nlp',
#  'Case_Rep_Med_2012_Dec_25_2012_168785.nxml.txt.nlp',
#  'BMJ_2009_Sep_15_339_b3360.nxml.txt.nlp',
#  'Soc_Cogn_Affect_Neurosci_2014_Aug_23_9(8)_1082-1088.nxml.txt.nlp',
#  'J_Hered_2012_Oct_19_Nov-Dec_103(6)_903-907.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_May_22_66(Pt_6)_m679.nxml.txt.nlp',
#  'Mol_Vis_2012_Jun_23_18_1719-1726.nxml.txt.nlp',
#  'Sensors_(Basel)_2012_May_29_12(6)_7095-7108.nxml.txt.nlp',
#  'Int_J_Integr_Care_2013_Feb_22_13_e003.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Dec_24_67(Pt_1)_o232.nxml.txt.nlp',
#  'Acta_Neuropathol_Commun_2015_Jan_17_3(1)_2.nxml.txt.nlp',
#  'Comput_Math_Methods_Med_2013_Sep_16_2013_985248.nxml.txt.nlp',
#  'Anal_Bioanal_Chem_2010_Dec_24_398(7-8)_2955-2961.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2006_May_12_8(4)_R89.nxml.txt.nlp',
#  'Cancer_Manag_Res_2011_Nov_18_3_311-317.nxml.txt.nlp',
#  'Indian_J_Ophthalmol_2007_Nov-Dec_55(6)_470-472.nxml.txt.nlp',
#  'Nat_Commun_2013_Sep_17_4_2464.nxml.txt.nlp',
#  'Oncoimmunology_2013_Aug_1_2(8)_e25461.nxml.txt.nlp',
#  'Mol_Microbiol_2013_Dec_8_90(6)_1147-1161.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Feb_3_66(Pt_3)_o515.nxml.txt.nlp',
#  'Diabetes_2013_Nov_18_62(11)_3828-3838.nxml.txt.nlp',
#  'Pan_Afr_Med_J_2014_May_2_18_9.nxml.txt.nlp',
#  'BMJ_2013_Sep_4_347_f5086.nxml.txt.nlp',
#  'Pharmaceuticals_(Basel)_2014_Jul_16_7(7)_839-849.nxml.txt.nlp',
#  'J_Agric_Food_Chem_2013_Feb_13_61(6)_1155-1159.nxml.txt.nlp',
#  'J_Oncol_2010_Mar_7_2010_616130.nxml.txt.nlp',
#  'J_Neuroengineering_Rehabil_2006_Jun_21_3_12.nxml.txt.nlp',
#  'Breast_Cancer_Res_Treat_2014_Apr_9_145(1)_73-82.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2009_Apr_21_4(8)_794-801.nxml.txt.nlp',
#  'Int_J_Nanomedicine_2008_Mar_3(1)_95-103.nxml.txt.nlp',
#  'Arch_Public_Health_2014_Aug_4_72(1)_26.nxml.txt.nlp',
#  'Diabetes_2009_Aug_28_58(8)_1863-1868.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Aug_7_2014_781246.nxml.txt.nlp',
#  'Br_J_Cancer_2009_Mar_10_100(5)_799-802.nxml.txt.nlp',
#  'Cases_J_2009_May_18_2_7517.nxml.txt.nlp',
#  'Indian_J_Anaesth_2012_Nov-Dec_56(6)_563-566.nxml.txt.nlp',
#  'Case_Rep_Transplant_2011_Jan_5_2011_210178.nxml.txt.nlp',
#  'FEBS_Open_Bio_2012_Sep_4_2_267-272.nxml.txt.nlp',
#  'Cytojournal_2014_Mar_20_11_6.nxml.txt.nlp',
#  'Child_Adolesc_Psychiatry_Ment_Health_2008_Jan_28_2_2.nxml.txt.nlp',
#  'Indian_J_Orthop_2007_Apr-Jun_41(2)_146-150.nxml.txt.nlp',
#  'Cardiovasc_Intervent_Radiol_2009_Jan_17_32(1)_192-194.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Jun_25_67(Pt_7)_o1805-o1806.nxml.txt.nlp',
#  'Front_Oncol_2013_Oct_1_3_237.nxml.txt.nlp',
#  'Crit_Care_2009_Mar_13_13(Suppl_1)_P482.nxml.txt.nlp',
#  'Diabetes_2013_Nov_18_62(11)_3658-3660.nxml.txt.nlp',
#  'J_Cell_Mol_Med_2013_Mar_7_17(3)_419-428.nxml.txt.nlp',
#  'Surg_Endosc_2014_Oct_23_28(3)_896-901.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2011_Nov_24_5_148.nxml.txt.nlp',
#  'Acta_Neuropathol_Commun_2014_Apr_8_2_40.nxml.txt.nlp',
#  'Environ_Health_Perspect_2008_Sep_21_116(9)_1218-1225.nxml.txt.nlp',
#  'J_RNAi_Gene_Silencing_2008_May_27_4(1)_295-301.nxml.txt.nlp',
#  'Behav_Neurol_2014_Apr_24_2014_215380.nxml.txt.nlp',
#  'Niger_Med_J_2011_Oct-Dec_52(4)_217-222.nxml.txt.nlp',
#  'Virulence_2013_Apr_1_4(3)_223-229.nxml.txt.nlp',
#  'Behav_Brain_Funct_2007_Jan_15_3_4.nxml.txt.nlp',
#  'ScientificWorldJournal_2013_Dec_12_2013_782745.nxml.txt.nlp',
#  'Mol_Brain_2014_Aug_1_7_54.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Jul_30_67(Pt_8)_o2143.nxml.txt.nlp',
#  'Extrem_Physiol_Med_2014_Apr_28_3_8.nxml.txt.nlp',
#  'Int_J_Community_Based_Nurs_Midwifery_2014_Jul_2(3)_128-135.nxml.txt.nlp',
#  'Indian_J_Nephrol_2014_Jan-Feb_24(1)_38-40.nxml.txt.nlp',
#  'Breast_Cancer_Res_2005_Feb_10_7(2)_64-69.nxml.txt.nlp',
#  'Mol_Vis_2012_Mar_31_18_779-785.nxml.txt.nlp',
#  'Breast_Cancer_Res_2012_Feb_8_14(1)_R26.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Aug_23_68(Pt_9)_m1180.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Nov_30_67(Pt_12)_o3463.nxml.txt.nlp',
#  'Mol_Cancer_2014_Jun_4_13_141.nxml.txt.nlp',
#  'Comp_Hepatol_2004_Jan_14_3(Suppl_1)_S53.nxml.txt.nlp',
#  'ScientificWorldJournal_2012_Apr_1_2012_687536.nxml.txt.nlp',
#  'Dev_Genes_Evol_2006_Oct_8_216(10)_565-577.nxml.txt.nlp',
#  'Cerebrospinal_Fluid_Res_2006_Dec_21_3(Suppl_1)_S42.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2014_Jun_20(6)_1082-1085.nxml.txt.nlp',
#  'Acta_Crystallogr_D_Biol_Crystallogr_2008_May_1_64(Pt_5)_543-550.nxml.txt.nlp',
#  'J_Clin_Biochem_Nutr_2010_Sep_23_47(2)_98-106.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2011_Feb_2_13(Suppl_1)_P351.nxml.txt.nlp',
#  'BMJ_Open_2014_Feb_13_4(2)_e003926.nxml.txt.nlp',
#  'Iran_J_Pharm_Res_2013_Summer_12(3)_457-469.nxml.txt.nlp',
#  'Pak_J_Med_Sci_2014_Mar-Apr_30(2)_295-298.nxml.txt.nlp',
#  'Oncotarget_2014_Aug_19_5(18)_8750-8764.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2010_Aug_65(8)_793b-798.nxml.txt.nlp',
#  'Acta_Orthop_2011_Oct_24_82(5)_606-609.nxml.txt.nlp',
#  'Neth_Heart_J_2014_Oct_4_22(10)_421-422.nxml.txt.nlp',
#  'Arch_Med_Sci_2014_Aug_29_10(4)_773-781.nxml.txt.nlp',
#  'Infection_2014_Oct_22_42(1)_61-71.nxml.txt.nlp',
#  'Cough_2008_Oct_19_4_9.nxml.txt.nlp',
#  'BMJ_2010_Mar_11_340_c912.nxml.txt.nlp',
#  'Front_Psychol_2013_Jan_17_3_590.nxml.txt.nlp',
#  'Hum_Genomics_Proteomics_2009_Nov_17_2009_374312.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Dec_24_67(Pt_1)_o203-o204.nxml.txt.nlp',
#  'Indian_J_Med_Res_2013_Oct_138(4)_549-556.nxml.txt.nlp',
#  'Cerebrovasc_Dis_Extra_2013_Apr_27_3(1)_74-77.nxml.txt.nlp',
#  'J_Cardiothorac_Surg_2011_Mar_18_6_31.nxml.txt.nlp',
#  'Crit_Care_2007_Mar_22_11(Suppl_2)_P425.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Dec_10_65(Pt_1)_o70.nxml.txt.nlp',
#  'J_Exp_Clin_Cancer_Res_2009_Apr_9_28(1)_49.nxml.txt.nlp',
#  'JSLS_2000_Oct-Dec_4(4)_281-285.nxml.txt.nlp',
#  'Am_J_Epidemiol_2012_Oct_15_176(8)_733-737.nxml.txt.nlp',
#  'Lab_Invest_2009_Nov_14_89(11)_1243-1251.nxml.txt.nlp',
#  'Biochemistry_2008_Jul_1_47(26)_6840-6850.nxml.txt.nlp',
#  'Mol_Imaging_Radionucl_Ther_2014_Feb_5_23(1)_16-20.nxml.txt.nlp',
#  'Scientifica_(Cairo)_2013_Dec_10_2013_691251.nxml.txt.nlp',
#  'Open_Dent_J_2014_Dec_12_8_220-228.nxml.txt.nlp',
#  'BMJ_2013_Jan_7_346_e8539.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2009_Jun_25_11(3)_233.nxml.txt.nlp',
#  'Expert_Rev_Mol_Med_2010_Sep_12_e27.nxml.txt.nlp',
#  'Ital_J_Pediatr_2011_May_14_37_21.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2014_Jul_69(7)_500-503.nxml.txt.nlp',
#  'Endosc_Ultrasound_2014_Jul-Sep_3(3)_152-160.nxml.txt.nlp',
#  'Ann_Biomed_Eng_2009_Dec_16_37(12)_2436-2448.nxml.txt.nlp',
#  'Infect_Agent_Cancer_2013_Sep_30_8_37.nxml.txt.nlp',
#  'Sensors_(Basel)_2013_Dec_2_13(12)_16533-16550.nxml.txt.nlp',
#  'Allergy_Asthma_Immunol_Res_2013_Jan_29_5(1)_55-58.nxml.txt.nlp',
#  'Multidiscip_Respir_Med_2014_May_30_9(1)_31.nxml.txt.nlp',
#  'Mol_Biol_Evol_2013_Nov_16_30(11)_2531-2540.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2007_Dec_6_64(Pt_1)_o203.nxml.txt.nlp',
#  'Oncotarget_2014_Oct_16_5(20)_9546-9563.nxml.txt.nlp',
#  'Environ_Health_Perspect_2008_Jun_26_116(6)_784-790.nxml.txt.nlp',
#  'Acta_Orthop_2010_Apr_6_81(2)_263-267.nxml.txt.nlp',
#  'Cancer_Cell_Int_2013_Mar_25_13_29.nxml.txt.nlp',
#  'Neural_Plast_2014_Jun_12_2014_127824.nxml.txt.nlp',
#  'Tuberc_Respir_Dis_(Seoul)_2012_Apr_30_72(4)_360-366.nxml.txt.nlp',
#  'J_Health_Popul_Nutr_2010_Jun_28(3)_281-285.nxml.txt.nlp',
#  'BMJ_2013_Jul_9_347_f4089.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2013_Oct_31_8(1)_452.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_May_29_2014_485620.nxml.txt.nlp',
#  'Crit_Care_2010_Mar_1_14(Suppl_1)_P339.nxml.txt.nlp',
#  'J_Insect_Sci_2002_Jun_28_2_11.nxml.txt.nlp',
#  'Emerg_Med_Int_2011_Oct_19_2011_813460.nxml.txt.nlp',
#  'Adv_Health_Sci_Educ_Theory_Pract_2011_Dec_25_16(5)_579-590.nxml.txt.nlp',
#  'Comput_Graph_2010_Aug_34(4)_361-369.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2014_Aug_23_70(Pt_9)_o1045-o1046.nxml.txt.nlp',
#  'Iran_J_Pharm_Res_2014_Autumn_13(4)_1387-1392.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Sep_14_67(Pt_10)_o2629.nxml.txt.nlp',
#  'Cardiovasc_Diabetol_2011_Dec_21_10_114.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2005_Feb_18_7(3)_R493-R502.nxml.txt.nlp',
#  'Pain_Res_Manag_2014_Nov-Dec_19(6)_e164-e167.nxml.txt.nlp',
#  'Sensors_(Basel)_2010_Nov_18_10(11)_10467-10483.nxml.txt.nlp',
#  'BMJ_Open_2014_Nov_8_4(11)_e006710.nxml.txt.nlp',
#  'Korean_Circ_J_2013_May_31_43(5)_287-292.nxml.txt.nlp',
#  'J_Med_Case_Reports_2011_May_14_5_184.nxml.txt.nlp',
#  'Adv_Bioinformatics_2009_Jul_20_2009_926450.nxml.txt.nlp',
#  'Front_Neurol_2014_Jul_17_5_133.nxml.txt.nlp',
#  'Indian_J_Psychiatry_2006_Oct-Dec_48(4)_251-253.nxml.txt.nlp',
#  'Cerebrum_2011_Jun_23_2011_10.nxml.txt.nlp',
#  'Iran_J_Basic_Med_Sci_2012_Jan-Feb_15(1)_602-607.nxml.txt.nlp',
#  'Hum_Genomics_2004_Aug_1_1(5)_375-380.nxml.txt.nlp',
#  'Front_Neurol_2011_Apr_4_2_21.nxml.txt.nlp',
#  'Influenza_Other_Respir_Viruses_2014_Jul_7_8(4)_389-396.nxml.txt.nlp',
#  'Br_J_Cancer_2009_Mar_10_100(5)_840-847.nxml.txt.nlp',
#  'Eur_J_Pediatr_2011_Nov_19_170(11)_1391-1400.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2014_Sep_18_8_734.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2011_Feb_2_13(Suppl_1)_P262.nxml.txt.nlp',
#  'Zookeys_2014_Sep_23_(442)_51-72.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Jun_3_2014_374562.nxml.txt.nlp',
#  'Sci_Rep_2014_Dec_1_4_7263.nxml.txt.nlp',
#  'Int_J_Gen_Med_2011_Sep_12_4_665-676.nxml.txt.nlp',
#  'Ann_Intensive_Care_2011_Nov_24_1_49.nxml.txt.nlp',
#  'Asian_J_Sports_Med_2013_Mar_20_4(1)_1-9.nxml.txt.nlp',
#  'Clin_Exp_Otorhinolaryngol_2014_Dec_14_7(4)_264-268.nxml.txt.nlp',
#  'Int_J_Hypertens_2013_Apr_22_2013_597906.nxml.txt.nlp',
#  'Global_Health_2010_Apr_19_6_5.nxml.txt.nlp',
#  'Neuroradiology_2011_May_23_53(5)_343-348.nxml.txt.nlp',
#  'Case_Rep_Oncol_Med_2013_Mar_14_2013_524305.nxml.txt.nlp',
#  'Open_Virol_J_2010_Jun_18_4_94-95.nxml.txt.nlp',
#  'Br_J_Cancer_2011_Sep_6_105(6)_760-765.nxml.txt.nlp',
#  'Crit_Care_2012_Mar_20_16(Suppl_1)_P230.nxml.txt.nlp',
#  'J_Biomed_Biotechnol_2003_Aug_20_2003(3)_208-211.nxml.txt.nlp',
#  'Ecancermedicalscience_2011_Feb_14_5_204.nxml.txt.nlp',
#  'Brain_Sci_2013_Jul_17_3(3)_1060-1075.nxml.txt.nlp',
#  'Acta_Crystallogr_D_Biol_Crystallogr_2009_Jun_1_65(Pt_6)_513-522.nxml.txt.nlp',
#  'Int_J_Appl_Basic_Med_Res_2014_Sep_4(Suppl_1)_S20-S22.nxml.txt.nlp',
#  'Indian_J_Anaesth_2010_Nov-Dec_54(6)_576a.nxml.txt.nlp',
#  'Ital_J_Pediatr_2014_Jan_8_40_2.nxml.txt.nlp',
#  'Hum_Mol_Genet_2012_May_1_21(9)_2111-2123.nxml.txt.nlp',
#  'Cell_Microbiol_2014_May_21_16(5)_632-641.nxml.txt.nlp',
#  'Cell_Commun_Signal_2009_Nov_23_7_26.nxml.txt.nlp',
#  'Mol_Biol_Cell_2014_Mar_1_25(5)_712-727.nxml.txt.nlp',
#  'Bioinorg_Chem_Appl_2012_Jul_31_2012_823830.nxml.txt.nlp',
#  'Anc_Sci_Life_2013_Apr-Jun_32(4)_212-216.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Feb_29_68(Pt_3)_o860-o861.nxml.txt.nlp',
#  'J_Gen_Physiol_2004_Apr_123(4)_377-386.nxml.txt.nlp',
#  'Biol_Direct_2010_Apr_20_5_27.nxml.txt.nlp',
#  'Breast_Cancer_Res_Treat_2012_Jun_2_133(3)_1143-1152.nxml.txt.nlp',
#  'Clin_Exp_Gastroenterol_2011_Oct_3_4_239-253.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Dec_18_67(Pt_1)_m101.nxml.txt.nlp',
#  'Indian_J_Orthop_2010_Jul-Sep_44(3)_308-313.nxml.txt.nlp',
#  'Genet_Vaccines_Ther_2010_May_12_8_3.nxml.txt.nlp',
#  'Physiol_Rep_2014_Sep_28_2(9)_e12155.nxml.txt.nlp',
#  'Endocrinology_2014_Sep_10_155(9)_3699-3712.nxml.txt.nlp',
#  'Ann_Dermatol_2014_Apr_30_26(2)_246-249.nxml.txt.nlp',
#  'Health_Econ_Rev_2012_Apr_4_2_5.nxml.txt.nlp',
#  'Glob_Health_Action_2014_Mar_14_7_10_3402_gha_v7_23499.nxml.txt.nlp',
#  'Front_Chem_2013_Aug_30_1_13.nxml.txt.nlp',
#  'Crit_Care_2011_Mar_11_15(Suppl_1)_P234.nxml.txt.nlp',
#  'Biosci_Rep_2013_Sep_25_33(5)_e00071.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jul_6_69(Pt_8)_o1216-o1217.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Dec_4_67(Pt_1)_m26.nxml.txt.nlp',
#  'J_Oncol_2012_Feb_6_2012_345164.nxml.txt.nlp',
#  'Leukemia_2013_May_1_27(5)_1072-1079.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Nov_9_67(Pt_12)_o3231-o3232.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Apr_18_65(Pt_5)_m523-m524.nxml.txt.nlp',
#  'Ayu_2010_Jan-Mar_31(1)_33-39.nxml.txt.nlp',
#  'Genome_Announc_2014_Feb_13_2(1)_e00065-14.nxml.txt.nlp',
#  'Int_J_Appl_Basic_Med_Res_2011_Jul-Dec_1(2)_120-122.nxml.txt.nlp',
#  'Biomed_Eng_Online_2013_Sep_10_12_90.nxml.txt.nlp',
#  'Virol_J_2011_Sep_23_8_448.nxml.txt.nlp',
#  'Case_Rep_Med_2014_Mar_17_2014_832592.nxml.txt.nlp',
#  'Indian_Dermatol_Online_J_2013_Oct-Dec_4(4)_279-282.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Sep_25_66(Pt_10)_o2636.nxml.txt.nlp',
#  'Cardiol_Res_Pract_2011_Oct_19_2011_348527.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2010_Oct_26_4_189.nxml.txt.nlp',
#  'Am_J_Cardiovasc_Drugs_2014_Oct_18_14(6)_451-462.nxml.txt.nlp',
#  'Reprod_Biol_Endocrinol_2013_Nov_26_11_109.nxml.txt.nlp',
#  'Genome_Announc_2014_Jul_24_2(4)_e00733-14.nxml.txt.nlp',
#  'ScientificWorldJournal_2014_Mar_13_2014_343715.nxml.txt.nlp',
#  'J_Biomed_Biotechnol_2010_May_10_2010_478732.nxml.txt.nlp',
#  'Acta_Orthop_2014_Dec_19_85(6)_626-632.nxml.txt.nlp',
#  'Clin_Pract_2011_Nov_21_1(4)_e118.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Aug_18_66(Pt_9)_o2303.nxml.txt.nlp',
#  'Chemother_Res_Pract_2011_Feb_15_2011_315418.nxml.txt.nlp',
#  'Genome_Med_2010_Oct_6_2(10)_74.nxml.txt.nlp',
#  'Scientifica_(Cairo)_2012_Dec_31_2012_126170.nxml.txt.nlp',
#  'Eur_J_Echocardiogr_2011_Jul_14_12(7)_520-527.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Apr_30_65(Pt_5)_o1168.nxml.txt.nlp',
#  'Bioinformatics_2013_Nov_1_29(21)_2714-2721.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Jun_30_66(Pt_7)_o1867.nxml.txt.nlp',
#  'Comp_Funct_Genomics_2010_Sep_20_2010_520238.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_May_16_68(Pt_6)_i45-i46.nxml.txt.nlp',
#  'Chiropr_Man_Therap_2011_Sep_24_19_23.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jun_27_65(Pt_7)_m829.nxml.txt.nlp',
#  'J_Med_Internet_Res_2005_Jun_21_7(2)_e16.nxml.txt.nlp',
#  'Crit_Care_2008_Mar_21_12(2)_R41.nxml.txt.nlp',
#  'Clinics_2008_Aug_63(4)_525-530.nxml.txt.nlp',
#  'Trials_2013_Nov_22_14_401.nxml.txt.nlp',
#  'Indian_J_Psychiatry_2009_Jan-Mar_51(1)_26-33.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Jan_7_68(Pt_2)_o256.nxml.txt.nlp',
#  'Am_J_Case_Rep_2014_Mar_25_15_123-127.nxml.txt.nlp',
#  'Bioinorg_Chem_Appl_2012_Oct_24_2012_649640.nxml.txt.nlp',
#  'Indian_Dermatol_Online_J_2014_Jul-Sep_5(3)_378-382.nxml.txt.nlp',
#  'ISRN_Obstet_Gynecol_2011_Dec_29_2011_472083.nxml.txt.nlp',
#  'J_Minim_Access_Surg_2006_Jun_2(2)_49-58.nxml.txt.nlp',
#  'Asian_J_Transfus_Sci_2008_Jul_2(2)_61-65.nxml.txt.nlp',
#  'EMBO_Mol_Med_2013_Nov_17_5(11)_1642-1661.nxml.txt.nlp',
#  'Neural_Plast_2012_Jun_26_2012_359728.nxml.txt.nlp',
#  'Crit_Care_2008_Mar_13_12(Suppl_2)_P120.nxml.txt.nlp',
#  'Brain_Behav_2012_Mar_2(2)_178-186.nxml.txt.nlp',
#  'ARYA_Atheroscler_2010_Spring_6(1)_23-30.nxml.txt.nlp',
#  'Genome_Announc_2014_Jan_30_2(1)_e01241-13.nxml.txt.nlp',
#  'Eur_J_Epidemiol_2010_Nov_22_25(11)_823-841.nxml.txt.nlp',
#  'J_Vis_Exp_2014_Feb_20_(84)_50893.nxml.txt.nlp',
#  'Iran_J_Basic_Med_Sci_2013_Apr_16(4)_660-663.nxml.txt.nlp',
#  'BMJ_Qual_Saf_2011_Apr_20(Suppl_1)_i62-i66.nxml.txt.nlp',
#  'Breast_Cancer_Res_2011_Dec_1_13(6)_R125.nxml.txt.nlp',
#  'Iran_J_Psychiatry_2014_Mar_9(1)_31-36.nxml.txt.nlp',
#  'Acta_Histochem_Cytochem_2011_Oct_26_44(5)_233-237.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Mar_31_66(Pt_4)_m485-m486.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2012_Jan_18(1)_188-189.nxml.txt.nlp',
#  'Reprod_Biol_Endocrinol_2004_Jun_16_2_39.nxml.txt.nlp',
#  'Front_Neuroenergetics_2012_Jul_5_4_8.nxml.txt.nlp',
#  'Ital_J_Pediatr_2012_Jul_23_38_34.nxml.txt.nlp',
#  'Theor_Appl_Genet_2012_Mar_20_124(5)_875-891.nxml.txt.nlp',
#  'Chem_Cent_J_2013_Apr_20_7_72.nxml.txt.nlp',
#  'Nat_Commun_2012_Jan_31_3_650.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2013_Nov_5_8(1)_461.nxml.txt.nlp',
#  'Indian_J_Ophthalmol_2010_Nov-Dec_58(6)_523-524.nxml.txt.nlp',
#  'Arch_Trauma_Res_2013_Jun_1_Spring_2(1)_3-10.nxml.txt.nlp',
#  'Indian_J_Med_Paediatr_Oncol_2013_Jul-Sep_34(3)_168-171.nxml.txt.nlp',
#  'J_Prev_Med_Public_Health_2012_Jul_31_45(4)_235-243.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jul_6_69(Pt_8)_m437.nxml.txt.nlp',
#  'Int_J_Gen_Med_2012_Mar_6_5_231-240.nxml.txt.nlp',
#  'Aging_Cell_2009_Dec_8(6)_752-755.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Apr_2_64(Pt_5)_o783.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2010_Oct_21_38(18)_6159-6175.nxml.txt.nlp',
#  'Arch_Med_Sci_2013_Aug_30_9(4)_601-607.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2012_Jul_24_40(Web_Server_issue)_W199-W204.nxml.txt.nlp',
#  'J_Phys_Ther_Sci_2014_Mar_25_26(3)_435-436.nxml.txt.nlp',
#  'Diabetes_2013_May_16_62(5)_1365-1366.nxml.txt.nlp',
#  'Int_J_Endocrinol_2009_Sep_29_2009_391284.nxml.txt.nlp',
#  'BMJ_Open_2015_Jan_10_5(1)_e006399.nxml.txt.nlp',
#  'Antimicrob_Resist_Infect_Control_2013_Jun_20_2(Suppl_1)_P278.nxml.txt.nlp',
#  'N_Am_J_Med_Sci_2012_Sep_4(9)_405-410.nxml.txt.nlp',
#  'Asian-Australas_J_Anim_Sci_2013_Oct_26(10)_1388-1398.nxml.txt.nlp',
#  'Indian_J_Orthop_2014_Nov-Dec_48(6)_632-633.nxml.txt.nlp',
#  'Eur_J_Dent_2011_Jan_5(1)_24-31.nxml.txt.nlp',
#  'ScientificWorldJournal_2014_Aug_5_2014_827124.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2012_Jul_9_40(12)_5415-5431.nxml.txt.nlp',
#  'Crit_Care_2004_Mar_15_8(Suppl_1)_P51.nxml.txt.nlp',
#  'Oncotarget_2014_Nov_12_5(20)_9626-9640.nxml.txt.nlp',
#  'Pan_Afr_Med_J_2012_Jun_8_12_25.nxml.txt.nlp',
#  'Health_Qual_Life_Outcomes_2012_Apr_30_10_45.nxml.txt.nlp',
#  'Front_Neurol_2014_Mar_24_5_29.nxml.txt.nlp',
#  'Med_Sci_Monit_2012_Jun_1_18(6)_BR247-BR252.nxml.txt.nlp',
#  'J_Cell_Biol_1998_Apr_20_141(2)_321-333.nxml.txt.nlp',
#  'J_Headache_Pain_2014_Apr_17_15(1)_20.nxml.txt.nlp',
#  'Front_Psychol_2015_Jan_8_5_1526.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Sep_30_67(Pt_10)_o2741.nxml.txt.nlp',
#  'Chemoecology_2009_Sep_7_19(3)_177-184.nxml.txt.nlp',
#  'Virol_J_2011_May_25_8_259.nxml.txt.nlp',
#  'Crit_Care_2011_Aug_16_15(4)_R200.nxml.txt.nlp',
#  'J_Anaesthesiol_Clin_Pharmacol_2012_Jan-Mar_28(1)_51-55.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jul_11_65(Pt_8)_m914.nxml.txt.nlp',
#  'Indian_J_Orthop_2008_Apr-Jun_42(2)_111-117.nxml.txt.nlp',
#  'J_Headache_Pain_2009_Apr_10_10(2)_135.nxml.txt.nlp',
#  'Int_Urogynecol_J_2010_Jun_5_21(6)_721-729.nxml.txt.nlp',
#  'Case_Rep_Med_2010_Sep_1_2010_202156.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Feb_12_67(Pt_3)_o619.nxml.txt.nlp',
#  'F1000Res_2013_Sep_24_2_196.nxml.txt.nlp',
#  'Int_J_Genomics_2013_Sep_3_2013_271347.nxml.txt.nlp',
#  'Cancer_Imaging_2005_Sep_21_5(1)_110-113.nxml.txt.nlp',
#  'Front_Microbiol_2014_May_13_5_217.nxml.txt.nlp',
#  'Psychiatry_Investig_2011_Sep_10_8(3)_269-271.nxml.txt.nlp',
#  'Indian_J_Anaesth_2012_Jan-Feb_56(1)_89-90.nxml.txt.nlp',
#  'Nat_Methods_2010_Aug_18_7(8)_634-636.nxml.txt.nlp',
#  'Case_Rep_Infect_Dis_2012_Jul_17_2012_916142.nxml.txt.nlp',
#  'J_Am_Heart_Assoc_2013_Apr_24_2(2)_e005868.nxml.txt.nlp',
#  'Mol_Cytogenet_2014_Jan_23_7_7.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2013_Jan_30_15(Suppl_1)_E20.nxml.txt.nlp',
#  'Br_J_Haematol_2013_May_11_161(4)_525-532.nxml.txt.nlp',
#  'Eur_Radiol_2011_Feb_22_21(2)_265-273.nxml.txt.nlp',
#  'Genome_Announc_2014_Feb_6_2(1)_e01253-13.nxml.txt.nlp',
#  'J_Cardiothorac_Surg_2013_Sep_11_8(Suppl_1)_P147.nxml.txt.nlp',
#  'BMJ_Open_2014_Oct_30_4(10)_e005341.nxml.txt.nlp',
#  'Case_Rep_Med_2010_Jun_9_2010_135029.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2012_Nov_15_14(11)_713-718.nxml.txt.nlp',
#  'Curr_Oncol_2009_May_16(3)_3-6.nxml.txt.nlp',
#  'Braz_J_Microbiol_2012_Jun_1_Apr-Jun_43(2)_627-634.nxml.txt.nlp',
#  'Allergy_Rhinol_(Providence)_2013_Fall_4(3)_e179-e183.nxml.txt.nlp',
#  'J_Med_Case_Rep_2014_Feb_10_8_41.nxml.txt.nlp',
#  'Biochem_Res_Int_2012_Mar_20_2012_749845.nxml.txt.nlp',
#  'Evid_Based_Complement_Alternat_Med_2011_Jan_9_2011_209879.nxml.txt.nlp',
#  'Ann_Rehabil_Med_2013_Oct_29_37(5)_628-632.nxml.txt.nlp',
#  'Int_J_Behav_Nutr_Phys_Act_2007_May_23_4_20.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2013_Mar_5_15(3)_177-182.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Mar_5_2014_193095.nxml.txt.nlp',
#  'J_Cancer_2012_Nov_1_3_454-458.nxml.txt.nlp',
#  'Biomed_Res_Int_2013_Jul_28_2013_983805.nxml.txt.nlp',
#  'Indian_Dermatol_Online_J_2014_Oct-Dec_5(4)_478-481.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Mar_6_66(Pt_4)_o759.nxml.txt.nlp',
#  'Ital_J_Pediatr_2009_Oct_23_35_30.nxml.txt.nlp',
#  'Chemother_Res_Pract_2012_Jul_15_2012_905796.nxml.txt.nlp',
#  'Acta_Pharmacol_Sin_2012_Jun_14_33(6)_761-766.nxml.txt.nlp',
#  'Crit_Care_1997_Nov_26_1(2)_61-64.nxml.txt.nlp',
#  'Environ_Health_Perspect_2009_Dec_7_117(12)_1809-1813.nxml.txt.nlp',
#  'Pharmacogn_Rev_2010_Jul-Dec_4(8)_195-199.nxml.txt.nlp',
#  'Indian_J_Radiol_Imaging_2010_Feb_20(1)_47-49.nxml.txt.nlp',
#  'Mol_Brain_2013_Dec_9_6_54.nxml.txt.nlp',
#  'Oncol_Lett_2013_Mar_10_5(3)_911-916.nxml.txt.nlp',
#  'Ann_Indian_Acad_Neurol_2013_Apr-Jun_16(2)_229-233.nxml.txt.nlp',
#  'Biomed_Opt_Express_2010_Dec_15_2(1)_100-112.nxml.txt.nlp',
#  'Pharmaceuticals_(Basel)_2013_Jul_1_6(7)_837-850.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2011_Jun_17(6)_1134-1135.nxml.txt.nlp',
#  'Age_(Dordr)_2012_Aug_7_34(4)_795-804.nxml.txt.nlp',
#  'Chem_Mater_2013_Dec_23_25(24)_4994-5003.nxml.txt.nlp',
#  'Mol_Microbiol_2013_Nov_16_90(4)_869-883.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Jul_31_64(Pt_8)_m1098-m1099.nxml.txt.nlp',
#  'Indian_J_Orthop_2014_Sep-Oct_48(5)_536a.nxml.txt.nlp',
#  'Case_Rep_Gastroenterol_2011_Mar_26_5(1)_100-109.nxml.txt.nlp',
#  'Tuberc_Respir_Dis_(Seoul)_2014_Oct_31_77(4)_193-196.nxml.txt.nlp',
#  'Springerplus_2015_Jan_17_4_26.nxml.txt.nlp',
#  'Croat_Med_J_2014_Feb_55(1)_54-60.nxml.txt.nlp',
#  'Mol_Cells_2014_Dec_31_37(12)_865a-872.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2014_Jan_16_16(Suppl_1)_P375.nxml.txt.nlp',
#  'Indian_J_Med_Res_2012_Nov_136(5)_766-775.nxml.txt.nlp',
#  'Eur_Spine_J_2008_Jul_25_17(7)_922-929.nxml.txt.nlp',
#  'Ann_Dermatol_2012_May_26_24(2)_194-199.nxml.txt.nlp',
#  'Case_Rep_Med_2010_Aug_8_2010_920568.nxml.txt.nlp',
#  'Int_J_Mol_Sci_2014_Jun_17_15(6)_10868-10891.nxml.txt.nlp',
#  'Indian_J_Pharm_Sci_2008_Mar-Apr_70(2)_249-251.nxml.txt.nlp',
#  'Insights_Imaging_2013_Apr_13_4(3)_357-367.nxml.txt.nlp',
#  'Front_Psychol_2014_Mar_11_5_191.nxml.txt.nlp',
#  'Cancers_(Basel)_2013_Sep_6_5(3)_1140-1162.nxml.txt.nlp',
#  'ISRN_Otolaryngol_2014_Apr_17_2014_238740.nxml.txt.nlp',
#  'J_Clin_Biochem_Nutr_2010_Sep_3_47(2)_138-147.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jun_20_65(Pt_7)_o1625.nxml.txt.nlp',
#  'Acta_Vet_Scand_2004_Sep_30_45(3)_133-137.nxml.txt.nlp',
#  'Arthritis_Res_2000_Dec_23_2(1)_16-32.nxml.txt.nlp',
#  'Dent_Res_J_(Isfahan)_2012_Dec_9(Suppl_1)_S1-S8.nxml.txt.nlp',
#  'Sensors_(Basel)_2014_Jul_17_14(7)_12784-12802.nxml.txt.nlp',
#  'Hematol_Rep_2010_Jul_23_2(1)_e5.nxml.txt.nlp',
#  'Ergonomics_2013_Dec_11_56(12)_1940-1944.nxml.txt.nlp',
#  'Endocrinology_2010_Jul_5_151(7)_3374-3385.nxml.txt.nlp',
#  'Tanaffos_2011_10(3)_63-66.nxml.txt.nlp',
#  'J_Indian_Assoc_Pediatr_Surg_2008_Jan-Mar_13(1)_22-24.nxml.txt.nlp',
#  'Case_Rep_Otolaryngol_2013_Mar_27_2013_690194.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2010_Feb_2_5(3)_533-538.nxml.txt.nlp',
#  'Int_J_Behav_Nutr_Phys_Act_2013_Feb_8_10_20.nxml.txt.nlp',
#  'Indian_J_Anaesth_2014_Nov-Dec_58(6)_765-766.nxml.txt.nlp',
#  'Mycobiology_2008_Mar_31_36(1)_40-44.nxml.txt.nlp',
#  'Cell_Death_Dis_2014_Jul_17_5(7)_e1335.nxml.txt.nlp',
#  'J_Biomed_Biotechnol_2008_Feb_14_2008_547428.nxml.txt.nlp',
#  'Diabetes_Care_2012_Jun_11_35(6)_1258-1264.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Mar_5_2014_576391.nxml.txt.nlp',
#  'Autoimmune_Dis_2013_Jun_20_2013_750814.nxml.txt.nlp',
#  'Diabetes_2013_Oct_17_62(10)_3341-3349.nxml.txt.nlp',
#  'Proteins_2011_Dec_22_79(12)_3381-3388.nxml.txt.nlp',
#  'Clin_Psychopharmacol_Neurosci_2014_Aug_12_12(2)_163-165.nxml.txt.nlp',
#  'J_Prev_Med_Public_Health_2012_May_31_45(3)_127-136.nxml.txt.nlp',
#  'Diabetes_Care_2010_Feb_10_33(2)_293-297.nxml.txt.nlp',
#  'Mol_Cancer_2012_Sep_11_11_66.nxml.txt.nlp',
#  'Biol_Open_2014_Nov_28_3(12)_1236-1244.nxml.txt.nlp',
#  'J_Med_Internet_Res_2003_Sep_29_5(3)_e23.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2008_Apr_9_10(1)_17.nxml.txt.nlp',
#  'Soc_Indic_Res_2011_Mar_12_101(1)_57-72.nxml.txt.nlp',
#  'Am_J_Obstet_Gynecol_2007_Jan_196(1)_62_e1-62_e5.nxml.txt.nlp',
#  'Cancers_(Basel)_2011_Aug_25_3(3)_3394-3404.nxml.txt.nlp',
#  'Arch_Med_Sci_2011_Apr_17_7(2)_257-263.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_May_31_68(Pt_6)_o1924.nxml.txt.nlp',
#  'Ind_Psychiatry_J_2013_Jan-Jun_22(1)_1-3.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Oct_29_67(Pt_11)_m1631.nxml.txt.nlp',
#  'Crit_Care_2008_Mar_13_12(Suppl_2)_P508.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Nov_21_65(Pt_12)_m1628-m1629.nxml.txt.nlp',
#  'Orphanet_J_Rare_Dis_2014_May_5_9_71.nxml.txt.nlp',
#  'Multidiscip_Respir_Med_2014_Oct_31_9(1)_53.nxml.txt.nlp',
#  'Front_Microbiol_2014_Nov_21_5_607.nxml.txt.nlp',
#  'Cardiol_Res_Pract_2014_Sep_10_2014_454701.nxml.txt.nlp',
#  'J_Gynecol_Oncol_2011_Sep_28_22(3)_196-202.nxml.txt.nlp',
#  'Croat_Med_J_2013_Dec_54(6)_507-509.nxml.txt.nlp',
#  'Eur_J_Psychotraumatol_2013_May_15_4_10_3402_ejpt_v4i0_20706.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Oct_28_65(Pt_11)_o2896-o2897.nxml.txt.nlp',
#  'Clin_Ophthalmol_2014_Mar_19_8_571-579.nxml.txt.nlp',
#  'Health_Care_Financ_Rev_1991_Summer_12(4)_87-97.nxml.txt.nlp',
#  'Croat_Med_J_2014_Feb_55(1)_10-13.nxml.txt.nlp',
#  'Ital_J_Pediatr_2009_May_12_35_12.nxml.txt.nlp',
#  'Clin_Pract_2014_Oct_3_4(2)_659.nxml.txt.nlp',
#  'Ann_Intensive_Care_2011_May_25_1_14.nxml.txt.nlp',
#  'EURASIP_J_Bioinform_Syst_Biol_2013_Sep_5_2013(1)_11.nxml.txt.nlp',
#  'Cancer_Cell_Int_2009_Oct_29_9_27.nxml.txt.nlp',
#  'Int_J_Health_Geogr_2013_Jan_17_12_2.nxml.txt.nlp',
#  'Exp_Ther_Med_2014_Mar_16_7(3)_529-536.nxml.txt.nlp',
#  'Diabetes_Care_2013_Aug_11_36(8)_2139-2141.nxml.txt.nlp',
#  'Iran_J_Basic_Med_Sci_2013_Aug_16(8)_950-954.nxml.txt.nlp',
#  'Int_J_Environ_Res_Public_Health_2011_Jan_19_8(1)_203-221.nxml.txt.nlp',
#  'Age_(Dordr)_2013_Jun_4_35(3)_719-732.nxml.txt.nlp',
#  'Pharm_Pract_(Granada)_2007_Nov_22_Oct-Dec_5(4)_169-173.nxml.txt.nlp',
#  'Surg_Neurol_Int_2010_Dec_31_1_97.nxml.txt.nlp',
#  'Cases_J_2008_Sep_10_1_148.nxml.txt.nlp',
#  'Scand_J_Prim_Health_Care_2014_Mar_32(1)_17-23.nxml.txt.nlp',
#  'Comput_Struct_Biotechnol_J_2012_Mar_20_1_e201204006.nxml.txt.nlp',
#  'Ital_J_Pediatr_2012_Aug_10_38_37.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2013_Feb_68(Suppl_1)_125-130.nxml.txt.nlp',
#  'Biomed_Res_Int_2013_Feb_14_2013_685142.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2014_Jul_5_16(7)_e16664.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Oct_9_66(Pt_11)_o2724.nxml.txt.nlp',
#  'Nat_Methods_2010_Jul_30_7(7)_554-559.nxml.txt.nlp',
#  'Front_Neurol_2013_Sep_12_4_134.nxml.txt.nlp',
#  'Cancer_Imaging_2011_Oct_3_11(1A)_S44-S47.nxml.txt.nlp',
#  'AIDS_Res_Treat_2010_Dec_19_2010_872396.nxml.txt.nlp',
#  'Ecol_Evol_2014_Mar_20_4(6)_826-830.nxml.txt.nlp',
#  'Philos_Trans_R_Soc_Lond_B_Biol_Sci_2011_Dec_27_366(1584)_3508-3520.nxml.txt.nlp',
#  'AIDS_Res_Ther_2006_Mar_31_3_8.nxml.txt.nlp',
#  'Alcohol_Res_2012_34(4)_391-400.nxml.txt.nlp',
#  'Front_Chem_2014_Feb_21_2_5.nxml.txt.nlp',
#  'Int_Cardiovasc_Res_J_2014_Sep_1_8(3)_99-104.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Jul_19_64(Pt_8)_o1547.nxml.txt.nlp',
#  'Sensors_(Basel)_2011_Jan_19_11(1)_1078-1087.nxml.txt.nlp',
#  'Appl_Surf_Sci_2013_May_15_273(100)_706-716.nxml.txt.nlp',
#  'Arthritis_Res_2002_Apr_8_4(3)_226-231.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2014_Jan_31_70(Pt_2)_m71-m72.nxml.txt.nlp',
#  'Gut_Liver_2013_Sep_11_7(5)_519-523.nxml.txt.nlp',
#  'EMBO_J_2013_Mar_6_32(5)_742-755.nxml.txt.nlp',
#  'Cardiol_Res_Pract_2011_May_24_2011_864964.nxml.txt.nlp',
#  'Indian_J_Urol_2007_Jul-Sep_23(3)_305-309.nxml.txt.nlp',
#  'Clin_Epidemiol_2010_Dec_12_2_281-288.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Apr_14_2014_232956.nxml.txt.nlp',
#  'Indian_J_Anaesth_2010_Nov-Dec_54(6)_485-488.nxml.txt.nlp',
#  'Oncol_Lett_2014_Jul_28_8(1)_404-408.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Sep_21_69(Pt_10)_o1567.nxml.txt.nlp',
#  'J_Surg_Case_Rep_2013_Jan_16_2013(1)_rjs018.nxml.txt.nlp',
#  'Autoimmune_Dis_2013_May_22_2013_593493.nxml.txt.nlp',
#  'Neural_Regen_Res_2014_Jul_1_9(13)_1297-1302.nxml.txt.nlp',
#  'J_Korean_Med_Sci_2011_Jan_22_26(1)_146-149.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Jul_9_64(Pt_8)_o1444.nxml.txt.nlp',
#  'Braz_J_Microbiol_2009_Sep_1_Jul-Sep_40(3)_670-677.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Sep_4_66(Pt_10)_o2479.nxml.txt.nlp',
#  'Anal_Chem_2009_Apr_1_81(7)_2768-2778.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Aug_6_64(Pt_9)_m1122-m1123.nxml.txt.nlp',
#  'J_Headache_Pain_2013_Feb_21_14(Suppl_1)_P93.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Jan_15_67(Pt_2)_o386.nxml.txt.nlp',
#  'J_Cell_Biol_2000_Feb_7_148(3)_531-542.nxml.txt.nlp',
#  'Spermatogenesis_2012_Jan_1_2(1)_23-31.nxml.txt.nlp',
#  'Ital_J_Pediatr_2010_Aug_17_36_55.nxml.txt.nlp',
#  'Asian_J_Transfus_Sci_2007_Jul-Dec_1(2)_47-51.nxml.txt.nlp',
#  'Int_J_Alzheimers_Dis_2011_Mar_17_2011_134971.nxml.txt.nlp',
#  'JMIR_Res_Protoc_2012_Jun_21_1(1)_e5.nxml.txt.nlp',
#  'Comput_Methods_Biomech_Biomed_Engin_2014_Jan_8_17(1)_48-63.nxml.txt.nlp',
#  'Oncol_Lett_2013_Oct_29_6(4)_1068-1078.nxml.txt.nlp',
#  'Nat_Commun_2013_4_10_1038_ncomms2973.nxml.txt.nlp',
#  'Gut_Microbes_2014_Jan_1_5(1)_74-82.nxml.txt.nlp',
#  'Indian_J_Endocrinol_Metab_2012_Dec_16(Suppl_2)_S416-S417.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jul_8_65(Pt_8)_m888.nxml.txt.nlp',
#  'Indian_J_Community_Med_2012_Apr-Jun_37(2)_107-115.nxml.txt.nlp',
#  'Nat_Commun_2012_Apr_24_3_791.nxml.txt.nlp',
#  'J_Immunol_Methods_2009_Jan_1_340(1)_11-24.nxml.txt.nlp',
#  'Indian_J_Crit_Care_Med_2015_Jan_19(1)_56-57.nxml.txt.nlp',
#  'Surg_Neurol_Int_2014_Mar_10_5(Suppl_1)_S39-S48.nxml.txt.nlp',
#  'Bioinform_Biol_Insights_2009_Sep_3_3_89-98.nxml.txt.nlp',
#  'Biomed_Opt_Express_2011_Mar_29_2(4)_996-1006.nxml.txt.nlp',
#  'Trials_2014_Dec_5_15(1)_479.nxml.txt.nlp',
#  'J_Prev_Med_Public_Health_2013_Jan_31_46(1)_39-49.nxml.txt.nlp',
#  'J_Headache_Pain_2008_Aug_26_9(4)_197-198.nxml.txt.nlp',
#  'Anat_Cell_Biol_2012_Mar_31_45(1)_26-37.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Aug_11_68(Pt_9)_o2697.nxml.txt.nlp',
#  'Crit_Care_2009_Mar_13_13(Suppl_1)_P384.nxml.txt.nlp',
#  'Genome_Announc_2014_Jan_30_2(1)_e01203-13.nxml.txt.nlp',
#  'BMJ_2014_Apr_29_348_g2688.nxml.txt.nlp',
#  'Crit_Care_2002_Nov_6_6(6)_468-470.nxml.txt.nlp',
#  'EPMA_J_2010_Mar_23_1(1)_56-72.nxml.txt.nlp',
#  'Cancer_Causes_Control_2011_Jan_12_22(1)_91-100.nxml.txt.nlp',
#  'Endothelium_2007_Nov_13_14(6)_345-351.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_May_5_68(Pt_6)_o1642.nxml.txt.nlp',
#  'Int_J_Biol_Sci_2013_Jul_5_9(6)_637-648.nxml.txt.nlp',
#  'Front_Neurol_2013_Mar_21_4_28.nxml.txt.nlp',
#  'Crit_Care_2008_Mar_13_12(Suppl_2)_P272.nxml.txt.nlp',
#  'Case_Rep_Pediatr_2012_Apr_1_2012_290645.nxml.txt.nlp',
#  'J_Res_Med_Sci_2012_Feb_17(2)_143-147.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Feb_12_67(Pt_3)_m322.nxml.txt.nlp',
#  'Bioinformatics_2013_Jun_15_29(12)_1526-1533.nxml.txt.nlp',
#  'J_Med_Internet_Res_2014_Feb_17_16(2)_e55.nxml.txt.nlp',
#  'Case_Rep_Med_2011_May_10_2011_502191.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Aug_23_69(Pt_9)_o1468.nxml.txt.nlp',
#  'Indian_J_Plast_Surg_2014_Jan-Apr_47(1)_116-119.nxml.txt.nlp',
#  'Ann_Neurosci_2013_Oct_20(4)_134-138.nxml.txt.nlp',
#  'Case_Rep_Med_2012_Aug_13_2012_585726.nxml.txt.nlp',
#  'Sensors_(Basel)_2014_Sep_4_14(9)_16532-16562.nxml.txt.nlp',
#  'Adv_Biomed_Res_2014_Jan_9_3_9.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Jul_25_65(Pt_8)_o1992-o1993.nxml.txt.nlp',
#  'Eur_J_Dent_2009_Oct_3(4)_343-347.nxml.txt.nlp',
#  'ARYA_Atheroscler_2014_Jul_10(4)_192-198.nxml.txt.nlp',
#  'Indian_J_Endocrinol_Metab_2012_May-Jun_16(3)_441-443.nxml.txt.nlp',
#  'World_Allergy_Organ_J_2012_Feb_17_5(Suppl_2)_S149b.nxml.txt.nlp',
#  'J_Breast_Cancer_2011_Sep_29_14(3)_213-218.nxml.txt.nlp',
#  'Crit_Care_2008_Mar_13_12(Suppl_2)_P223.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Aug_20_64(Pt_9)_o1792.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Aug_6_64(Pt_9)_m1119.nxml.txt.nlp',
#  'Cancer_Inform_2007_Feb_6_3_29-41.nxml.txt.nlp',
#  'Br_J_Cancer_2009_Jul_7_101(1)_12-18.nxml.txt.nlp',
#  'J_Med_Internet_Res_2006_Jul_28_8(3)_e13.nxml.txt.nlp',
#  'J_Health_Popul_Nutr_2006_Sep_24(3)_277-281.nxml.txt.nlp',
#  'World_Allergy_Organ_J_2012_Feb_17_5(Suppl_2)_S144c.nxml.txt.nlp',
#  'Soc_Psychiatry_Psychiatr_Epidemiol_2007_Apr_12_42(4)_288-294.nxml.txt.nlp',
#  'Case_Rep_Emerg_Med_2013_May_30_2013_583287.nxml.txt.nlp',
#  'Indian_J_Pharm_Sci_2012_Jan-Feb_74(1)_63-68.nxml.txt.nlp',
#  'Curr_Rev_Musculoskelet_Med_2007_Nov_2_1(1)_1-11.nxml.txt.nlp',
#  'Iran_J_Reprod_Med_2014_Sep_12(9)_633-640.nxml.txt.nlp',
#  'Can_J_Psychiatry_2014_Jul_59(7)_349-357.nxml.txt.nlp',
#  'Mol_Cancer_2012_Jun_21_11_42.nxml.txt.nlp',
#  'Pak_J_Med_Sci_2013_Apr_29(2)_485-489.nxml.txt.nlp',
#  'J_Korean_Neurosurg_Soc_2014_Oct_31_56(4)_303-309.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Apr_8_65(Pt_5)_m487-m488.nxml.txt.nlp',
#  'F1000_Biol_Rep_2009_Apr_29_1_32.nxml.txt.nlp',
#  'Trials_2012_Sep_24_13_175.nxml.txt.nlp',
#  'Clin_Drug_Investig_2014_Nov_9_34(2)_107-115.nxml.txt.nlp',
#  'Oncol_Lett_2014_Jun_12_7(6)_2113-2117.nxml.txt.nlp',
#  'Crit_Care_2005_Jun_9_9(Suppl_2)_P72.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2013_Apr_68(4)_463-468.nxml.txt.nlp',
#  'Indian_J_Plast_Surg_2010_Jul-Dec_43(2)_228-229.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2011_Jan_12_6(1)_76.nxml.txt.nlp',
#  'Allergy_2011_Mar_66(3)_351-359.nxml.txt.nlp',
#  'Crit_Care_2014_Mar_17_18(Suppl_1)_P301.nxml.txt.nlp',
#  'Int_J_Behav_Med_2011_Jun_5_18(2)_172.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jul_31_69(Pt_8)_o1361.nxml.txt.nlp',
#  'Virchows_Arch_2012_Feb_23_460(2)_129-130.nxml.txt.nlp',
#  'Eplasty_2012_Apr_24_12_e20.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2014_Jun_27_8_385.nxml.txt.nlp',
#  'Ann_Lab_Med_2014_May_8_34(3)_187-197.nxml.txt.nlp',
#  'Trials_2014_Oct_24_15(1)_405.nxml.txt.nlp',
#  'Int_J_Equity_Health_2014_Feb_14_13_17.nxml.txt.nlp',
#  'Clin_Mol_Allergy_2010_Mar_25_8_6.nxml.txt.nlp',
#  'Algorithms_Mol_Biol_2010_Jun_23_5_27.nxml.txt.nlp',
#  'Indian_Pacing_Electrophysiol_J_2013_Mar_7_13(2)_94-98.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2012_Dec_67(12)_1357-1360.nxml.txt.nlp',
#  'J_Cell_Mol_Med_2014_Nov_30_18(11)_2321-2330.nxml.txt.nlp',
#  'J_Korean_Med_Sci_2005_Aug_31_20(4)_618-623.nxml.txt.nlp',
#  'Indian_J_Med_Res_2012_Apr_135(4)_469-478.nxml.txt.nlp',
#  'Addict_Health_2011_Summer-Autumn_3(3-4)_79-84.nxml.txt.nlp',
#  'Can_J_Infect_Dis_Med_Microbiol_2014_Sep-Oct_25(5)_257-264.nxml.txt.nlp',
#  'Front_Neurosci_2014_Jun_11_8_153.nxml.txt.nlp',
#  'Case_Rep_Neurol_Med_2014_Dec_9_2014_272084.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2010_Sep_65(9)_931-933.nxml.txt.nlp',
#  'N_Am_J_Med_Sci_2013_Aug_5(8)_480-485.nxml.txt.nlp',
#  'Acta_Inform_Med_2012_Sep_20(3)_180-185.nxml.txt.nlp',
#  'Genetica_2014_Mar_28_142(2)_141-148.nxml.txt.nlp',
#  'J_Biol_Eng_2013_Apr_9_7_9.nxml.txt.nlp',
#  'Mol_Biol_Evol_2014_Jun_27_31(6)_1402-1413.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2003_Feb_24_5(Suppl_1)_94.nxml.txt.nlp',
#  'An_Bras_Dermatol_2012_Nov-Dec_87(6)_884-890.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2010_Sep_30_66(Pt_10)_m1328.nxml.txt.nlp',
#  'Case_Rep_Med_2011_Jun_23_2011_387570.nxml.txt.nlp',
#  'Front_Neurosci_2012_Jan_5_5_146.nxml.txt.nlp',
#  'Ann_Med_Health_Sci_Res_2014_Nov-Dec_4(6)_852-857.nxml.txt.nlp',
#  'J_Ophthalmol_2011_May_25_2011_769571.nxml.txt.nlp',
#  'Alcohol_Res_Health_2008_31(2)_148-154.nxml.txt.nlp',
#  'Indian_J_Dermatol_2013_Sep-Oct_58(5)_407b.nxml.txt.nlp',
#  'Asian-Australas_J_Anim_Sci_2014_Feb_27(2)_237-246.nxml.txt.nlp',
#  'Cancer_Cell_Int_2013_Aug_16_13_81.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2013_Jun_68(6)_797-802.nxml.txt.nlp',
#  'Scientifica_(Cairo)_2012_Dec_23_2012_857516.nxml.txt.nlp',
#  'Cerebrospinal_Fluid_Res_2006_Dec_21_3(Suppl_1)_S28.nxml.txt.nlp',
#  'Pan_Afr_Med_J_2014_May_1_17_324.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Apr_5_69(Pt_5)_o652.nxml.txt.nlp',
#  'Front_Genet_2014_Jan_28_5_2.nxml.txt.nlp',
#  'Virol_J_2009_Apr_28_6_44.nxml.txt.nlp',
#  'Ann_Rehabil_Med_2012_Apr_30_36(2)_173-181.nxml.txt.nlp',
#  'FASEB_J_2014_Feb_28(2)_923-934.nxml.txt.nlp',
#  'J_Radiat_Res_2013_Jul_54(Suppl_1)_i23-i30.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Oct_5_69(Pt_11)_m585.nxml.txt.nlp',
#  'Genome_Biol_2005_Mar_29_6(4)_R33.nxml.txt.nlp',
#  'Behav_Brain_Funct_2013_Aug_12_9_33.nxml.txt.nlp',
#  'Mol_Biol_Evol_2013_Jul_29_30(7)_1687-1699.nxml.txt.nlp',
#  'Genome_Announc_2014_Jul_24_2(4)_e00677-14.nxml.txt.nlp',
#  'Int_J_Environ_Res_Public_Health_2010_Jun_21_7(6)_2692-2707.nxml.txt.nlp',
#  'Front_Behav_Neurosci_2009_Sep_9_3_29.nxml.txt.nlp',
#  'eLife_2014_May_13_3_e02270.nxml.txt.nlp',
#  'Int_J_Biomed_Sci_2014_Mar_10(1)_31-35.nxml.txt.nlp',
#  'J_Phys_Ther_Sci_2014_Aug_30_26(8)_1193-1198.nxml.txt.nlp',
#  'ScientificWorldJournal_2014_Nov_25_2014_279614.nxml.txt.nlp',
#  'Breast_Cancer_Res_2004_Jun_29_6(5)_R488-R498.nxml.txt.nlp',
#  'J_Clin_Biochem_Nutr_2011_Nov_17_49(3)_188-194.nxml.txt.nlp',
#  'Ital_J_Pediatr_2011_May_17_37_23.nxml.txt.nlp',
#  'Surg_Neurol_Int_2013_Apr_18_4_57.nxml.txt.nlp',
#  'J_Biomed_Sci_2014_Jul_22_21(1)_65.nxml.txt.nlp',
#  'Mol_Cytogenet_2008_Jun_19_1_13.nxml.txt.nlp',
#  'Indian_J_Urol_2014_Jan-Mar_30(1)_23-27.nxml.txt.nlp',
#  'Drugs_R_D_2012_Dec_23_12(4)_207-216.nxml.txt.nlp',
#  'Front_Plant_Sci_2012_Jun_1_3_118.nxml.txt.nlp',
#  'Adv_Cogn_Psychol_2012_Feb_15_8(1)_38-49.nxml.txt.nlp',
#  'Clin_Ophthalmol_2011_Dec_14_5_1771-1776.nxml.txt.nlp',
#  'J_Int_AIDS_Soc_2012_Nov_19_15(2)_17383.nxml.txt.nlp',
#  'Case_Rep_Neurol_2014_Apr_30_6(1)_126-133.nxml.txt.nlp',
#  'Int_J_Mol_Sci_2014_Jun_27_15(7)_11539-11554.nxml.txt.nlp',
#  'Croat_Med_J_2012_Oct_53(5)_450-460.nxml.txt.nlp',
#  'Pan_Afr_Med_J_2014_Sep_4_19_7.nxml.txt.nlp',
#  'Breast_Cancer_Res_2009_Nov_5_11(6)_R79.nxml.txt.nlp',
#  'Environ_Health_Perspect_2007_Sep_13_115(9)_1293-1297.nxml.txt.nlp',
#  'Mol_Cancer_2009_Aug_28_8_68.nxml.txt.nlp',
#  'Nanoscale_Res_Lett_2013_Oct_24_8(1)_441.nxml.txt.nlp',
#  'J_Health_Popul_Nutr_2011_Aug_29(4)_317-326.nxml.txt.nlp',
#  'Crit_Care_2008_Jul_29_12(4)_R94.nxml.txt.nlp',
#  'Trials_2013_Apr_1_14_89.nxml.txt.nlp',
#  'Biochemistry_2013_Feb_5_52(5)_773-785.nxml.txt.nlp',
#  'Breast_Cancer_Res_Treat_2012_Apr_25_132(3)_1049-1062.nxml.txt.nlp',
#  'Iran_J_Psychiatry_2014_Apr_9(2)_55-63.nxml.txt.nlp',
#  'Case_Rep_Gastroenterol_2013_Aug_17_7(2)_347-351.nxml.txt.nlp',
#  'Emerg_Infect_Dis_2012_Jul_18(7)_1196-1200.nxml.txt.nlp',
#  'Acta_Orthop_2012_Apr_24_83(2)_121-128.nxml.txt.nlp',
#  'Curr_Neuropharmacol_2007_Dec_5(4)_224-231.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jun_8_69(Pt_7)_o1056.nxml.txt.nlp',
#  'J_Cell_Biol_2001_Oct_15_155(2)_207-216.nxml.txt.nlp',
#  'Nat_Biotechnol_2010_Sep_28(9)_904-906.nxml.txt.nlp',
#  'Genome_Biol_2000_Aug_4_1(2)_reviews1009_1-reviews1009_4.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2003_Sep_12_5(Suppl_3)_119.nxml.txt.nlp',
#  'Perspect_Med_Educ_2014_Apr_18_3(2)_101-112.nxml.txt.nlp',
#  'Int_J_Cardiovasc_Imaging_2013_Jan_23_29(1)_29-38.nxml.txt.nlp',
#  'Int_J_Equity_Health_2011_Nov_2_10_46.nxml.txt.nlp',
#  'Case_Rep_Neurol_Med_2013_Feb_28_2013_540947.nxml.txt.nlp',
#  'J_Cardiovasc_Magn_Reson_2013_Jan_30_15(Suppl_1)_O61.nxml.txt.nlp',
#  'Ann_Dermatol_2014_Jun_12_26(3)_381-384.nxml.txt.nlp',
#  'Acta_Histochem_Cytochem_2006_Aug_30_39(4)_113-123.nxml.txt.nlp',
#  'Protein_Cell_2014_Feb_30_5(2)_151-159.nxml.txt.nlp',
#  'Breast_Cancer_Res_2011_Jun_9_13(3)_R58.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_Nov_14_68(Pt_12)_o3343.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Jun_13_64(Pt_7)_o1260.nxml.txt.nlp',
#  'Case_Rep_Med_2012_Oct_10_2012_659104.nxml.txt.nlp',
#  'Int_Semin_Surg_Oncol_2006_Mar_7_3_6.nxml.txt.nlp',
#  'J_Health_Popul_Nutr_2011_Jun_29(3)_200-206.nxml.txt.nlp',
#  'Int_J_Appl_Basic_Med_Res_2013_Jul-Dec_3(2)_98-105.nxml.txt.nlp',
#  'Iran_Red_Crescent_Med_J_2014_Feb_3_16(2)_e14627.nxml.txt.nlp',
#  'BMJ_2013_Aug_6_347_f4585.nxml.txt.nlp',
#  'Drug_Target_Insights_2007_Feb_12_2_29-38.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2012_May_31_68(Pt_6)_o1970-o1971.nxml.txt.nlp',
#  'Adv_Biomed_Res_2014_Nov_29_3_241.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2008_Oct_15_64(Pt_11)_m1392-m1393.nxml.txt.nlp',
#  'ScientificWorldJournal_2012_Oct_11_2012_516358.nxml.txt.nlp',
#  'Mucosal_Immunol_2013_Mar_29_6(2)_358-368.nxml.txt.nlp',
#  'APSP_J_Case_Rep_2013_May_15_4(2)_18.nxml.txt.nlp',
#  'ScientificWorldJournal_2012_Apr_26_2012_342468.nxml.txt.nlp',
#  'Indian_J_Urol_2009_Jan-Mar_25(1)_40-46.nxml.txt.nlp',
#  'Oncoimmunology_2014_Jun_18_3_e29081.nxml.txt.nlp',
#  'Nat_Chem_Biol_2010_Jan_29_6(1)_22-24.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Dec_7_68(Pt_1)_o29-o30.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2011_Aug_27_67(Pt_9)_o2505-o2506.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Jan_12_69(Pt_2)_o220.nxml.txt.nlp',
#  'Clin_Exp_Gastroenterol_2013_May_6_6_43-49.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2013_Feb_16_69(Pt_3)_o384.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2011_Feb_66(2)_267-274.nxml.txt.nlp',
#  'Contemp_Clin_Dent_2013_Apr-Jun_4(2)_243-247.nxml.txt.nlp',
#  'Cognit_Ther_Res_2012_Dec_27_36(6)_731-739.nxml.txt.nlp',
#  'Comp_Cytogenet_2012_Nov_19_6(4)_371-377.nxml.txt.nlp',
#  'Biomed_Res_Int_2014_Jan_12_2014_356964.nxml.txt.nlp',
#  'Comput_Math_Methods_Med_2014_Feb_26_2014_761536.nxml.txt.nlp',
#  'Indian_J_Ophthalmol_2011_Jan-Feb_59(1)_37-40.nxml.txt.nlp',
#  'Clin_Pharmacol_2013_Oct_3_5(Suppl_1)_55-61.nxml.txt.nlp',
#  'J_Lipid_Res_2013_Feb_54(2)_425-435.nxml.txt.nlp',
#  'Clinics_(Sao_Paulo)_2013_Feb_68(2)_193-198.nxml.txt.nlp',
#  'Int_J_Environ_Res_Public_Health_2010_Apr_25_7(4)_1285-1301.nxml.txt.nlp',
#  'Ann_Indian_Acad_Neurol_2013_Apr-Jun_16(2)_255-258.nxml.txt.nlp',
#  'J_Cardiothorac_Surg_2011_Aug_9_6_95.nxml.txt.nlp',
#  'J_Cell_Biol_2004_Jan_5_164(1)_97-109.nxml.txt.nlp',
#  'Int_J_Health_Geogr_2007_Mar_6_6_6.nxml.txt.nlp',
#  'Acta_Crystallogr_Sect_E_Struct_Rep_Online_2009_Feb_28_65(Pt_3)_o651.nxml.txt.nlp',
#  'Anticancer_Agents_Med_Chem_2010_Dec_10(10)_753-768.nxml.txt.nlp',
#  'Chiropr_Osteopat_2010_Sep_1_18_25.nxml.txt.nlp',
#  'AJP_Rep_2012_Nov_26_2(1)_39-42.nxml.txt.nlp',
#  'Head_Face_Med_2007_Jan_31_3_8.nxml.txt.nlp',
#  'Arthritis_Res_Ther_2006_Jul_19_8(4)_R117.nxml.txt.nlp',
#  'Cases_J_2008_Nov_25_1_352.nxml.txt.nlp',
#  'Eplasty_2009_Nov_23_9_e57.nxml.txt.nlp',
#  'Ecol_Evol_2012_Jul_2(7)_1682-1695.nxml.txt.nlp',
#  'Colomb_Med_(Cali)_44(4)_243-246.nxml.txt.nlp',
#  'Nat_Commun_2013_Nov_15_4_2808.nxml.txt.nlp',
#  'J_Biomed_Biotechnol_2010_Mar_22_2010_121094.nxml.txt.nlp',
#  'Front_Hum_Neurosci_2014_Dec_3_8_965.nxml.txt.nlp',
#  'Comput_Math_Methods_Med_2013_Apr_16_2013_908591.nxml.txt.nlp',
#  'Nucleic_Acids_Res_2014_Dec_16_42(22)_e170.nxml.txt.nlp',
#  'Clin_Toxicol_(Phila)_2011_Nov_14_49(9)_794-798.nxml.txt.nlp',
#  'J_Biol_Chem_2013_May_24_288(21)_15256-15267.nxml.txt.nlp',
#  'Case_Rep_Anesthesiol_2011_Jan_18_2011_841510.nxml.txt.nlp',
#  'Front_Immunol_2013_May_31_4_129.nxml.txt.nlp',
#  ...]

# %% [markdown]
# Now the sentences need to be tagged to their appropriate section and concatenated into one string per section per document.
#
# The sentences are assigned a section by whichever section they are closest to (that is less than their sentence number). For example, if introduction had sentence number 5 and methods had sentence number 25, sentence number 20 would be assigned to introduction.
#
# This is done for each sentence in each document and joined by spaces into a one string per section per document. Finally, only the documents that contain an introduction, discussion, and conclusion are kept and put into the validDocsDict dictionary

# %%
documentDict = defaultdict(list)
docPartsDict = defaultdict(lambda : defaultdict(list))
docPartsCombinedDict = defaultdict(dict)

for item in sentObjList:
    documentDict[item.document].append(item)
    
for document in documentDict.keys():
    docSentList = documentDict[document]
    introNum = int(headingsDict[document].get("introduction", -1))
    methoNum = int(headingsDict[document].get("methods", -1))
    resultNum = int(headingsDict[document].get("results", -1))
    discussNum = int(headingsDict[document].get("discussion", -1))
    conclusionNum = int(headingsDict[document].get("conclusion", -1))
    refNum = int(headingsDict[document].get("references", -1))

    for sent in docSentList:
        label = "noSection"
        dist = int(sent.sentenceNumber)
        sentNumber = int(sent.sentenceNumber)
        
        if dist > sentNumber - introNum and sentNumber - introNum > 0:
            label = "introduction"
            dist = sentNumber - introNum
        if dist > sentNumber - methoNum and sentNumber - methoNum > 0:
            label = "methods"
            dist = sentNumber - methoNum
        if dist > sentNumber - resultNum and sentNumber - resultNum > 0:
            label = "results"
            dist = sentNumber - resultNum
        if dist > sentNumber - discussNum and sentNumber - discussNum > 0:
            label = "discussion"
            dist = sentNumber - discussNum
        if dist > sentNumber - conclusionNum and sentNumber - conclusionNum > 0:
            label = "conclusion"
            dist = sentNumber - conclusionNum
        if dist > sentNumber - refNum and sentNumber - refNum > 0:
            label = "references"
            dist = sentNumber - refNum
        if sent.sentence.strip().lower() not in ["introduction", "methods", "results", "discussion", "conclusion", "references"]:
            docPartsDict[document][label].append(sent)
    
    for x in docPartsDict[document].keys():
        docPartsCombinedDict[document][x] = " ".join(" ".join(y.posList) for y in sorted(docPartsDict[document][x], key=lambda z: z.sentenceNumber))

validDocsDict = defaultdict(dict)

for doc in docPartsCombinedDict.keys():
    tempKeys = docPartsCombinedDict[doc].keys()
    if 'introduction' in tempKeys and 'discussion' in tempKeys and 'conclusion' in tempKeys:
        validDocsDict[doc] = docPartsCombinedDict[doc]

print(str(len(docPartsCombinedDict.keys())))
print(str(len(validDocsDict.keys())))
# Out:
# 9981
# 1268

# %% [markdown]
# Take the valid documents in the validDocsDict and output to a pickle file with the key part_docid with the part being introduction, methods, etc. and the docid allowing for document tracking.

# %%
outputDict = dict()
for doc in validDocsDict.keys():
    for part in validDocsDict[doc].keys():
        outputDict[part + "_" + doc] = validDocsDict[doc][part]

pickle.dump(outputDict, open("PubmedPos35.p", "wb"))
